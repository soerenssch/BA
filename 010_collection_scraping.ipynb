# %%
# Packages
import requests
import pandas as pd
import time
import sqlite3
import json

# %% [markdown]
# # OpenSea

# %%
def fetch_page(url, headers, params, max_retries=5):
    """
    Makes a GET request to the given URL with built-in retry logic for 5xx errors.
    Returns the JSON response or None if the retries fail.
    """
    for attempt in range(max_retries):
        try:
            response = requests.get(url, headers=headers, params=params)
            
            # If successful response, return the parsed JSON
            if response.status_code == 200:
                return response.json()
            
            # If it's a server error (5xx), we can retry
            elif 500 <= response.status_code < 600:
                print(f"Server error {response.status_code} on attempt {attempt+1}. Retrying...")
                time.sleep(2 ** attempt)  # Exponential backoff: 2^0=1s, 2^1=2s, 2^2=4s ...
            else:
                # For other error codes (400-range, etc.), decide what you want to do
                print(f"Unexpected error {response.status_code}: {response.text}")
                return None
        
        except requests.exceptions.RequestException as e:
            # Network errors, timeouts, etc.
            print(f"Request exception: {e}. Attempt {attempt+1}. Retrying...")
            time.sleep(2 ** attempt)
    
    # If we got here, all retries failed
    print(f"Failed after {max_retries} attempts. Returning None.")
    return None


def create_table_if_not_exists(conn):
    """
    Create a table named 'collections' if it doesn't exist.
    """
    
    create_sql = """
    CREATE TABLE IF NOT EXISTS collections (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        collection_slug TEXT,
        name TEXT,
        description TEXT,
        image_url TEXT,
        banner_image_url TEXT,
        owner TEXT,
        safelist_status TEXT,
        category TEXT,
        is_disabled INTEGER,
        is_nsfw INTEGER,
        trait_offers_enabled INTEGER,
        collection_offers_enabled INTEGER,
        opensea_url TEXT,
        project_url TEXT,
        wiki_url TEXT,
        discord_url TEXT,
        telegram_url TEXT,
        twitter_username TEXT,
        instagram_username TEXT,
        contract_info TEXT
    )
    """
    conn.execute(create_sql)
    conn.commit()


def insert_collections(conn, collections_data):
    """
    Insert a list of collection dicts into the 'collections' table.
    For the 'contracts' array, we only store the first item as 'address:chain'.
    """
    insert_sql = """
    INSERT INTO collections (
        collection_slug,
        name,
        description,
        image_url,
        banner_image_url,
        owner,
        safelist_status,
        category,
        is_disabled,
        is_nsfw,
        trait_offers_enabled,
        collection_offers_enabled,
        opensea_url,
        project_url,
        wiki_url,
        discord_url,
        telegram_url,
        twitter_username,
        instagram_username,
        contract_info
    ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """

    data_to_insert = []
    for item in collections_data:
        # Extract first contract address:chain if it exists
        contracts = item.get("contracts", [])
        if contracts:
            first_contract = contracts[0]
            contract_info = f"{first_contract.get('address','')}:{first_contract.get('chain','')}"
        else:
            contract_info = ""

        row = (
            item.get("collection", ""),  # collection_slug
            item.get("name", ""),
            item.get("description", ""),
            item.get("image_url", ""),
            item.get("banner_image_url", ""),
            item.get("owner", ""),
            item.get("safelist_status", ""),
            item.get("category", ""),
            1 if item.get("is_disabled", False) else 0,
            1 if item.get("is_nsfw", False) else 0,
            1 if item.get("trait_offers_enabled", False) else 0,
            1 if item.get("collection_offers_enabled", False) else 0,
            item.get("opensea_url", ""),
            item.get("project_url", ""),
            item.get("wiki_url", ""),
            item.get("discord_url", ""),
            item.get("telegram_url", ""),
            item.get("twitter_username", ""),
            item.get("instagram_username", ""),
            contract_info
        )
        data_to_insert.append(row)

    conn.executemany(insert_sql, data_to_insert)
    conn.commit()


def fetch_all_collections(api_key, max_pages=None):
    """
    Fetch as many NFT collections as possible from OpenSea using the 
    paginated /api/v2/collections endpoint. Each page gets written to
    opensea_collections.db immediately.
    
    :param api_key:    Your OpenSea API key
    :param max_pages:  Integer maximum pages to fetch, or None to keep going.
    """
    base_url = "https://api.opensea.io/api/v2/collections"
    headers = {
        "Accept": "application/json",
        "x-api-key": api_key
    }

    # Connect to SQLite DB (on disk). The file is created if it doesn't exist
    conn = sqlite3.connect("data/opensea_collections.db")
    create_table_if_not_exists(conn)

    page_count = 0
    next_cursor = None

    while True:
        params = {
            "limit": 100,
            "order_by": "created_date"
        }
        if next_cursor:
            params["next"] = next_cursor

        data = fetch_page(base_url, headers, params, max_retries=5)
        if not data:
            print("No data returned (or retries exhausted). Stopping.")
            break
        
        collections_data = data.get("collections", [])
        if not collections_data:
            print("No more collections returned. Stopping.")
            break

        # Write the fetched collections into the DB
        insert_collections(conn, collections_data)

        page_count += 1
        print(f"Fetched {len(collections_data)} collections on page {page_count}.")

        # If we have a max_pages limit, stop once reached
        if max_pages and page_count >= max_pages:
            print(f"Reached max_pages={max_pages}. Stopping.")
            break

        # Check for the 'next' cursor for pagination
        next_cursor = data.get("next")
        if not next_cursor:
            print("No next cursor returned. Completed pagination.")
            break

        # Optional small delay to avoid rate limiting
        # time.sleep(0.25)

    conn.close()
    print(f"Finished. Pages fetched: {page_count}")

# %%
# Execution

if __name__ == "__main__":
    OPENSEA_API_KEY = "your_key"
    fetch_all_collections(OPENSEA_API_KEY, max_pages=30000)
# Out:
# Fetched 100 collections on page 1.
# Fetched 100 collections on page 2.
# Fetched 100 collections on page 3.
# Fetched 100 collections on page 4.
# Fetched 100 collections on page 5.
# Fetched 100 collections on page 6.
# Fetched 100 collections on page 7.
# Fetched 100 collections on page 8.
# Fetched 100 collections on page 9.
# Fetched 100 collections on page 10.
# Fetched 100 collections on page 11.
# Fetched 100 collections on page 12.
# Fetched 100 collections on page 13.
# Fetched 100 collections on page 14.
# Fetched 100 collections on page 15.
# Fetched 100 collections on page 16.
# Fetched 100 collections on page 17.
# Fetched 100 collections on page 18.
# Fetched 100 collections on page 19.
# Fetched 100 collections on page 20.
# Fetched 100 collections on page 21.
# Fetched 100 collections on page 22.
# Fetched 100 collections on page 23.
# Fetched 100 collections on page 24.
# Fetched 100 collections on page 25.
# Fetched 100 collections on page 26.
# Fetched 100 collections on page 27.
# Fetched 100 collections on page 28.
# Fetched 100 collections on page 29.
# Fetched 100 collections on page 30.
# Fetched 100 collections on page 31.
# Fetched 100 collections on page 32.
# Fetched 100 collections on page 33.
# Fetched 100 collections on page 34.
# Fetched 100 collections on page 35.
# Fetched 100 collections on page 36.
# Fetched 100 collections on page 37.
# Fetched 100 collections on page 38.
# Fetched 100 collections on page 39.
# Fetched 100 collections on page 40.
# Fetched 100 collections on page 41.
# Fetched 100 collections on page 42.
# Fetched 100 collections on page 43.
# Fetched 100 collections on page 44.
# Fetched 100 collections on page 45.
# Fetched 100 collections on page 46.
# Fetched 100 collections on page 47.
# Fetched 100 collections on page 48.
# Fetched 100 collections on page 49.
# Fetched 100 collections on page 50.
# Fetched 100 collections on page 51.
# Fetched 100 collections on page 52.
# Fetched 100 collections on page 53.
# Fetched 100 collections on page 54.
# Fetched 100 collections on page 55.
# Fetched 100 collections on page 56.
# Fetched 100 collections on page 57.
# Fetched 100 collections on page 58.
# Fetched 100 collections on page 59.
# Fetched 100 collections on page 60.
# Fetched 100 collections on page 61.
# Fetched 100 collections on page 62.
# Fetched 100 collections on page 63.
# Fetched 100 collections on page 64.
# Fetched 100 collections on page 65.
# Fetched 100 collections on page 66.
# Fetched 100 collections on page 67.
# Fetched 100 collections on page 68.
# Fetched 100 collections on page 69.
# Fetched 100 collections on page 70.
# Fetched 100 collections on page 71.
# Fetched 100 collections on page 72.
# Fetched 100 collections on page 73.
# Fetched 100 collections on page 74.
# Fetched 100 collections on page 75.
# Fetched 100 collections on page 76.
# Fetched 100 collections on page 77.
# Fetched 100 collections on page 78.
# Fetched 100 collections on page 79.
# Fetched 100 collections on page 80.
# Fetched 100 collections on page 81.
# Fetched 100 collections on page 82.
# Fetched 100 collections on page 83.
# Fetched 100 collections on page 84.
# Fetched 100 collections on page 85.
# Fetched 100 collections on page 86.
# Fetched 100 collections on page 87.
# Fetched 100 collections on page 88.
# Fetched 100 collections on page 89.
# Fetched 100 collections on page 90.
# Fetched 100 collections on page 91.
# Fetched 100 collections on page 92.
# Fetched 100 collections on page 93.
# Fetched 100 collections on page 94.
# Fetched 100 collections on page 95.
# Fetched 100 collections on page 96.
# Fetched 100 collections on page 97.
# Fetched 100 collections on page 98.
# Fetched 100 collections on page 99.
# Fetched 100 collections on page 100.
# Fetched 100 collections on page 101.
# Fetched 100 collections on page 102.
# Fetched 100 collections on page 103.
# Fetched 100 collections on page 104.
# Fetched 100 collections on page 105.
# Fetched 100 collections on page 106.
# Fetched 100 collections on page 107.
# Fetched 100 collections on page 108.
# Fetched 100 collections on page 109.
# Fetched 100 collections on page 110.
# Fetched 100 collections on page 111.
# Fetched 100 collections on page 112.
# Fetched 100 collections on page 113.
# Fetched 100 collections on page 114.
# Fetched 100 collections on page 115.
# Fetched 100 collections on page 116.
# Fetched 100 collections on page 117.
# Fetched 100 collections on page 118.
# Fetched 100 collections on page 119.
# Fetched 100 collections on page 120.
# Fetched 100 collections on page 121.
# Fetched 100 collections on page 122.
# Fetched 100 collections on page 123.
# Fetched 100 collections on page 124.
# Fetched 100 collections on page 125.
# Fetched 100 collections on page 126.
# Fetched 100 collections on page 127.
# Fetched 100 collections on page 128.
# Fetched 100 collections on page 129.
# Fetched 100 collections on page 130.
# Fetched 100 collections on page 131.
# Fetched 100 collections on page 132.
# Fetched 100 collections on page 133.
# Fetched 100 collections on page 134.
# Fetched 100 collections on page 135.
# Fetched 100 collections on page 136.
# Fetched 100 collections on page 137.
# Fetched 100 collections on page 138.
# Fetched 100 collections on page 139.
# Fetched 100 collections on page 140.
# Fetched 100 collections on page 141.
# Fetched 100 collections on page 142.
# Fetched 100 collections on page 143.
# Fetched 100 collections on page 144.
# Fetched 100 collections on page 145.
# Fetched 100 collections on page 146.
# Fetched 100 collections on page 147.
# Fetched 100 collections on page 148.
# Fetched 100 collections on page 149.
# Fetched 100 collections on page 150.
# Fetched 100 collections on page 151.
# Fetched 100 collections on page 152.
# Fetched 100 collections on page 153.
# Fetched 100 collections on page 154.
# Fetched 100 collections on page 155.
# Fetched 100 collections on page 156.
# Fetched 100 collections on page 157.
# Fetched 100 collections on page 158.
# Fetched 100 collections on page 159.
# Fetched 100 collections on page 160.
# Fetched 100 collections on page 161.
# Fetched 100 collections on page 162.
# Fetched 100 collections on page 163.
# Fetched 100 collections on page 164.
# Fetched 100 collections on page 165.
# Fetched 100 collections on page 166.
# Fetched 100 collections on page 167.
# Fetched 100 collections on page 168.
# Fetched 100 collections on page 169.
# Fetched 100 collections on page 170.
# Fetched 100 collections on page 171.
# Fetched 100 collections on page 172.
# Fetched 100 collections on page 173.
# Fetched 100 collections on page 174.
# Fetched 100 collections on page 175.
# Fetched 100 collections on page 176.
# Fetched 100 collections on page 177.
# Fetched 100 collections on page 178.
# Fetched 100 collections on page 179.
# Fetched 100 collections on page 180.
# Fetched 100 collections on page 181.
# Fetched 100 collections on page 182.
# Fetched 100 collections on page 183.
# Fetched 100 collections on page 184.
# Fetched 100 collections on page 185.
# Fetched 100 collections on page 186.
# Fetched 100 collections on page 187.
# Fetched 100 collections on page 188.
# Fetched 100 collections on page 189.
# Fetched 100 collections on page 190.
# Fetched 100 collections on page 191.
# Fetched 100 collections on page 192.
# Fetched 100 collections on page 193.
# Fetched 100 collections on page 194.
# Fetched 100 collections on page 195.
# Fetched 100 collections on page 196.
# Fetched 100 collections on page 197.
# Fetched 100 collections on page 198.
# Fetched 100 collections on page 199.
# Fetched 100 collections on page 200.
# Fetched 100 collections on page 201.
# Fetched 100 collections on page 202.
# Fetched 100 collections on page 203.
# Fetched 100 collections on page 204.
# Fetched 100 collections on page 205.
# Fetched 100 collections on page 206.
# Fetched 100 collections on page 207.
# Fetched 100 collections on page 208.
# Fetched 100 collections on page 209.
# Fetched 100 collections on page 210.
# Fetched 100 collections on page 211.
# Fetched 100 collections on page 212.
# Fetched 100 collections on page 213.
# Fetched 100 collections on page 214.
# Fetched 100 collections on page 215.
# Fetched 100 collections on page 216.
# Fetched 100 collections on page 217.
# Fetched 100 collections on page 218.
# Fetched 100 collections on page 219.
# Fetched 100 collections on page 220.
# Fetched 100 collections on page 221.
# Fetched 100 collections on page 222.
# Fetched 100 collections on page 223.
# Fetched 100 collections on page 224.
# Fetched 100 collections on page 225.
# Fetched 100 collections on page 226.
# Fetched 100 collections on page 227.
# Fetched 100 collections on page 228.
# Fetched 100 collections on page 229.
# Fetched 100 collections on page 230.
# Fetched 100 collections on page 231.
# Fetched 100 collections on page 232.
# Fetched 100 collections on page 233.
# Fetched 100 collections on page 234.
# Fetched 100 collections on page 235.
# Fetched 100 collections on page 236.
# Fetched 100 collections on page 237.
# Fetched 100 collections on page 238.
# Fetched 100 collections on page 239.
# Fetched 100 collections on page 240.
# Fetched 100 collections on page 241.
# Fetched 100 collections on page 242.
# Fetched 100 collections on page 243.
# Fetched 100 collections on page 244.
# Fetched 100 collections on page 245.
# Fetched 100 collections on page 246.
# Fetched 100 collections on page 247.
# Fetched 100 collections on page 248.
# Fetched 100 collections on page 249.
# Fetched 100 collections on page 250.
# Fetched 100 collections on page 251.
# Fetched 100 collections on page 252.
# Fetched 100 collections on page 253.
# Fetched 100 collections on page 254.
# Fetched 100 collections on page 255.
# Fetched 100 collections on page 256.
# Fetched 100 collections on page 257.
# Fetched 100 collections on page 258.
# Fetched 100 collections on page 259.
# Fetched 100 collections on page 260.
# Fetched 100 collections on page 261.
# Fetched 100 collections on page 262.
# Fetched 100 collections on page 263.
# Fetched 100 collections on page 264.
# Fetched 100 collections on page 265.
# Fetched 100 collections on page 266.
# Fetched 100 collections on page 267.
# Fetched 100 collections on page 268.
# Fetched 100 collections on page 269.
# Fetched 100 collections on page 270.
# Fetched 100 collections on page 271.
# Fetched 100 collections on page 272.
# Fetched 100 collections on page 273.
# Fetched 100 collections on page 274.
# Fetched 100 collections on page 275.
# Fetched 100 collections on page 276.
# Fetched 100 collections on page 277.
# Fetched 100 collections on page 278.
# Fetched 100 collections on page 279.
# Fetched 100 collections on page 280.
# Fetched 100 collections on page 281.
# Fetched 100 collections on page 282.
# Fetched 100 collections on page 283.
# Fetched 100 collections on page 284.
# Fetched 100 collections on page 285.
# Fetched 100 collections on page 286.
# Fetched 100 collections on page 287.
# Fetched 100 collections on page 288.
# Fetched 100 collections on page 289.
# Fetched 100 collections on page 290.
# Fetched 100 collections on page 291.
# Fetched 100 collections on page 292.
# Fetched 100 collections on page 293.
# Fetched 100 collections on page 294.
# Fetched 100 collections on page 295.
# Fetched 100 collections on page 296.
# Fetched 100 collections on page 297.
# Fetched 100 collections on page 298.
# Fetched 100 collections on page 299.
# Fetched 100 collections on page 300.
# Fetched 100 collections on page 301.
# Fetched 100 collections on page 302.
# Fetched 100 collections on page 303.
# Fetched 100 collections on page 304.
# Fetched 100 collections on page 305.
# Fetched 100 collections on page 306.
# Fetched 100 collections on page 307.
# Fetched 100 collections on page 308.
# Fetched 100 collections on page 309.
# Fetched 100 collections on page 310.
# Fetched 100 collections on page 311.
# Fetched 100 collections on page 312.
# Fetched 100 collections on page 313.
# Fetched 100 collections on page 314.
# Fetched 100 collections on page 315.
# Fetched 100 collections on page 316.
# Fetched 100 collections on page 317.
# Fetched 100 collections on page 318.
# Fetched 100 collections on page 319.
# Fetched 100 collections on page 320.
# Fetched 100 collections on page 321.
# Fetched 100 collections on page 322.
# Fetched 100 collections on page 323.
# Fetched 100 collections on page 324.
# Fetched 100 collections on page 325.
# Fetched 100 collections on page 326.
# Fetched 100 collections on page 327.
# Fetched 100 collections on page 328.
# Fetched 100 collections on page 329.
# Fetched 100 collections on page 330.
# Fetched 100 collections on page 331.
# Fetched 100 collections on page 332.
# Fetched 100 collections on page 333.
# Fetched 100 collections on page 334.
# Fetched 100 collections on page 335.
# Fetched 100 collections on page 336.
# Fetched 100 collections on page 337.
# Fetched 100 collections on page 338.
# Fetched 100 collections on page 339.
# Fetched 100 collections on page 340.
# Fetched 100 collections on page 341.
# Fetched 100 collections on page 342.
# Fetched 100 collections on page 343.
# Fetched 100 collections on page 344.
# Fetched 100 collections on page 345.
# Fetched 100 collections on page 346.
# Fetched 100 collections on page 347.
# Fetched 100 collections on page 348.
# Fetched 100 collections on page 349.
# Fetched 100 collections on page 350.
# Fetched 100 collections on page 351.
# Fetched 100 collections on page 352.
# Fetched 100 collections on page 353.
# Fetched 100 collections on page 354.
# Fetched 100 collections on page 355.
# Fetched 100 collections on page 356.
# Fetched 100 collections on page 357.
# Fetched 100 collections on page 358.
# Fetched 100 collections on page 359.
# Fetched 100 collections on page 360.
# Fetched 100 collections on page 361.
# Fetched 100 collections on page 362.
# Fetched 100 collections on page 363.
# Fetched 100 collections on page 364.
# Fetched 100 collections on page 365.
# Fetched 100 collections on page 366.
# Fetched 100 collections on page 367.
# Fetched 100 collections on page 368.
# Fetched 100 collections on page 369.
# Fetched 100 collections on page 370.
# Fetched 100 collections on page 371.
# Fetched 100 collections on page 372.
# Fetched 100 collections on page 373.
# Fetched 100 collections on page 374.
# Fetched 100 collections on page 375.
# Fetched 100 collections on page 376.
# Fetched 100 collections on page 377.
# Fetched 100 collections on page 378.
# Fetched 100 collections on page 379.
# Fetched 100 collections on page 380.
# Fetched 100 collections on page 381.
# Fetched 100 collections on page 382.
# Fetched 100 collections on page 383.
# Fetched 100 collections on page 384.
# Fetched 100 collections on page 385.
# Fetched 100 collections on page 386.
# Fetched 100 collections on page 387.
# Fetched 100 collections on page 388.
# Fetched 100 collections on page 389.
# Fetched 100 collections on page 390.
# Fetched 100 collections on page 391.
# Fetched 100 collections on page 392.
# Fetched 100 collections on page 393.
# Fetched 100 collections on page 394.
# Fetched 100 collections on page 395.
# Fetched 100 collections on page 396.
# Fetched 100 collections on page 397.
# Fetched 100 collections on page 398.
# Fetched 100 collections on page 399.
# Fetched 100 collections on page 400.
# Fetched 100 collections on page 401.
# Fetched 100 collections on page 402.
# Fetched 100 collections on page 403.
# Fetched 100 collections on page 404.
# Fetched 100 collections on page 405.
# Fetched 100 collections on page 406.
# Fetched 100 collections on page 407.
# Fetched 100 collections on page 408.
# Fetched 100 collections on page 409.
# Fetched 100 collections on page 410.
# Fetched 100 collections on page 411.
# Fetched 100 collections on page 412.
# Fetched 100 collections on page 413.
# Fetched 100 collections on page 414.
# Fetched 100 collections on page 415.
# Fetched 100 collections on page 416.
# Fetched 100 collections on page 417.
# Fetched 100 collections on page 418.
# Fetched 100 collections on page 419.
# Fetched 100 collections on page 420.
# Fetched 100 collections on page 421.
# Fetched 100 collections on page 422.
# Fetched 100 collections on page 423.
# Fetched 100 collections on page 424.
# Fetched 100 collections on page 425.
# Fetched 100 collections on page 426.
# Fetched 100 collections on page 427.
# Fetched 100 collections on page 428.
# Fetched 100 collections on page 429.
# Fetched 100 collections on page 430.
# Fetched 100 collections on page 431.
# Fetched 100 collections on page 432.
# Fetched 100 collections on page 433.
# Fetched 100 collections on page 434.
# Fetched 100 collections on page 435.
# Fetched 100 collections on page 436.
# Fetched 100 collections on page 437.
# Fetched 100 collections on page 438.
# Fetched 100 collections on page 439.
# Fetched 100 collections on page 440.
# Fetched 100 collections on page 441.
# Fetched 100 collections on page 442.
# Fetched 100 collections on page 443.
# Fetched 100 collections on page 444.
# Fetched 100 collections on page 445.
# Fetched 100 collections on page 446.
# Fetched 100 collections on page 447.
# Fetched 100 collections on page 448.
# Fetched 100 collections on page 449.
# Fetched 100 collections on page 450.
# Fetched 100 collections on page 451.
# Fetched 100 collections on page 452.
# Fetched 100 collections on page 453.
# Fetched 100 collections on page 454.
# Fetched 100 collections on page 455.
# Fetched 100 collections on page 456.
# Fetched 100 collections on page 457.
# Fetched 100 collections on page 458.
# Fetched 100 collections on page 459.
# Fetched 100 collections on page 460.
# Fetched 100 collections on page 461.
# Fetched 100 collections on page 462.
# Fetched 100 collections on page 463.
# Fetched 100 collections on page 464.
# Fetched 100 collections on page 465.
# Fetched 100 collections on page 466.
# Fetched 100 collections on page 467.
# Fetched 100 collections on page 468.
# Fetched 100 collections on page 469.
# Fetched 100 collections on page 470.
# Fetched 100 collections on page 471.
# Fetched 100 collections on page 472.
# Fetched 100 collections on page 473.
# Fetched 100 collections on page 474.
# Fetched 100 collections on page 475.
# Fetched 100 collections on page 476.
# Fetched 100 collections on page 477.
# Fetched 100 collections on page 478.
# Fetched 100 collections on page 479.
# Fetched 100 collections on page 480.
# Fetched 100 collections on page 481.
# Fetched 100 collections on page 482.
# Fetched 100 collections on page 483.
# Fetched 100 collections on page 484.
# Fetched 100 collections on page 485.
# Fetched 100 collections on page 486.
# Fetched 100 collections on page 487.
# Fetched 100 collections on page 488.
# Fetched 100 collections on page 489.
# Fetched 100 collections on page 490.
# Fetched 100 collections on page 491.
# Fetched 100 collections on page 492.
# Fetched 100 collections on page 493.
# Fetched 100 collections on page 494.
# Fetched 100 collections on page 495.
# Fetched 100 collections on page 496.
# Fetched 100 collections on page 497.
# Fetched 100 collections on page 498.
# Fetched 100 collections on page 499.
# Fetched 100 collections on page 500.
# Fetched 100 collections on page 501.
# Fetched 100 collections on page 502.
# Fetched 100 collections on page 503.
# Fetched 100 collections on page 504.
# Fetched 100 collections on page 505.
# Fetched 100 collections on page 506.
# Fetched 100 collections on page 507.
# Fetched 100 collections on page 508.
# Fetched 100 collections on page 509.
# Fetched 100 collections on page 510.
# Fetched 100 collections on page 511.
# Fetched 100 collections on page 512.
# Fetched 100 collections on page 513.
# Fetched 100 collections on page 514.
# Fetched 100 collections on page 515.
# Fetched 100 collections on page 516.
# Fetched 100 collections on page 517.
# Fetched 100 collections on page 518.
# Fetched 100 collections on page 519.
# Fetched 100 collections on page 520.
# Fetched 100 collections on page 521.
# Fetched 100 collections on page 522.
# Fetched 100 collections on page 523.
# Fetched 100 collections on page 524.
# Fetched 100 collections on page 525.
# Fetched 100 collections on page 526.
# Fetched 100 collections on page 527.
# Fetched 100 collections on page 528.
# Fetched 100 collections on page 529.
# Fetched 100 collections on page 530.
# Fetched 100 collections on page 531.
# Fetched 100 collections on page 532.
# Fetched 100 collections on page 533.
# Fetched 100 collections on page 534.
# Fetched 100 collections on page 535.
# Fetched 100 collections on page 536.
# Fetched 100 collections on page 537.
# Fetched 100 collections on page 538.
# Fetched 100 collections on page 539.
# Fetched 100 collections on page 540.
# Fetched 100 collections on page 541.
# Fetched 100 collections on page 542.
# Fetched 100 collections on page 543.
# Fetched 100 collections on page 544.
# Fetched 100 collections on page 545.
# Fetched 100 collections on page 546.
# Fetched 100 collections on page 547.
# Fetched 100 collections on page 548.
# Fetched 100 collections on page 549.
# Fetched 100 collections on page 550.
# Fetched 100 collections on page 551.
# Fetched 100 collections on page 552.
# Fetched 100 collections on page 553.
# Fetched 100 collections on page 554.
# Fetched 100 collections on page 555.
# Fetched 100 collections on page 556.
# Fetched 100 collections on page 557.
# Fetched 100 collections on page 558.
# Fetched 100 collections on page 559.
# Fetched 100 collections on page 560.
# Fetched 100 collections on page 561.
# Fetched 100 collections on page 562.
# Fetched 100 collections on page 563.
# Fetched 100 collections on page 564.
# Fetched 100 collections on page 565.
# Fetched 100 collections on page 566.
# Fetched 100 collections on page 567.
# Fetched 100 collections on page 568.
# Fetched 100 collections on page 569.
# Fetched 100 collections on page 570.
# Fetched 100 collections on page 571.
# Fetched 100 collections on page 572.
# Fetched 100 collections on page 573.
# Fetched 100 collections on page 574.
# Fetched 100 collections on page 575.
# Fetched 100 collections on page 576.
# Fetched 100 collections on page 577.
# Fetched 100 collections on page 578.
# Fetched 100 collections on page 579.
# Fetched 100 collections on page 580.
# Fetched 100 collections on page 581.
# Fetched 100 collections on page 582.
# Fetched 100 collections on page 583.
# Fetched 100 collections on page 584.
# Fetched 100 collections on page 585.
# Fetched 100 collections on page 586.
# Fetched 100 collections on page 587.
# Fetched 100 collections on page 588.
# Fetched 100 collections on page 589.
# Fetched 100 collections on page 590.
# Fetched 100 collections on page 591.
# Fetched 100 collections on page 592.
# Fetched 100 collections on page 593.
# Fetched 100 collections on page 594.
# Fetched 100 collections on page 595.
# Fetched 100 collections on page 596.
# Fetched 100 collections on page 597.
# Fetched 100 collections on page 598.
# Fetched 100 collections on page 599.
# Fetched 100 collections on page 600.
# Fetched 100 collections on page 601.
# Fetched 100 collections on page 602.
# Fetched 100 collections on page 603.
# Fetched 100 collections on page 604.
# Fetched 100 collections on page 605.
# Fetched 100 collections on page 606.
# Fetched 100 collections on page 607.
# Fetched 100 collections on page 608.
# Fetched 100 collections on page 609.
# Fetched 100 collections on page 610.
# Fetched 100 collections on page 611.
# Fetched 100 collections on page 612.
# Fetched 100 collections on page 613.
# Fetched 100 collections on page 614.
# Fetched 100 collections on page 615.
# Fetched 100 collections on page 616.
# Fetched 100 collections on page 617.
# Fetched 100 collections on page 618.
# Fetched 100 collections on page 619.
# Fetched 100 collections on page 620.
# Fetched 100 collections on page 621.
# Fetched 100 collections on page 622.
# Fetched 100 collections on page 623.
# Fetched 100 collections on page 624.
# Fetched 100 collections on page 625.
# Fetched 100 collections on page 626.
# Fetched 100 collections on page 627.
# Fetched 100 collections on page 628.
# Fetched 100 collections on page 629.
# Fetched 100 collections on page 630.
# Fetched 100 collections on page 631.
# Fetched 100 collections on page 632.
# Fetched 100 collections on page 633.
# Fetched 100 collections on page 634.
# Fetched 100 collections on page 635.
# Fetched 100 collections on page 636.
# Fetched 100 collections on page 637.
# Fetched 100 collections on page 638.
# Fetched 100 collections on page 639.
# Fetched 100 collections on page 640.
# Fetched 100 collections on page 641.
# Fetched 100 collections on page 642.
# Fetched 100 collections on page 643.
# Fetched 100 collections on page 644.
# Fetched 100 collections on page 645.
# Fetched 100 collections on page 646.
# Fetched 100 collections on page 647.
# Fetched 100 collections on page 648.
# Fetched 100 collections on page 649.
# Fetched 100 collections on page 650.
# Fetched 100 collections on page 651.
# Fetched 100 collections on page 652.
# Fetched 100 collections on page 653.
# Fetched 100 collections on page 654.
# Fetched 100 collections on page 655.
# Fetched 100 collections on page 656.
# Fetched 100 collections on page 657.
# Fetched 100 collections on page 658.
# Fetched 100 collections on page 659.
# Fetched 100 collections on page 660.
# Fetched 100 collections on page 661.
# Fetched 100 collections on page 662.
# Fetched 100 collections on page 663.
# Fetched 100 collections on page 664.
# Fetched 100 collections on page 665.
# Fetched 100 collections on page 666.
# Fetched 100 collections on page 667.
# Fetched 100 collections on page 668.
# Fetched 100 collections on page 669.
# Fetched 100 collections on page 670.
# Fetched 100 collections on page 671.
# Fetched 100 collections on page 672.
# Fetched 100 collections on page 673.
# Fetched 100 collections on page 674.
# Fetched 100 collections on page 675.
# Fetched 100 collections on page 676.
# Fetched 100 collections on page 677.
# Fetched 100 collections on page 678.
# Fetched 100 collections on page 679.
# Fetched 100 collections on page 680.
# Fetched 100 collections on page 681.
# Fetched 100 collections on page 682.
# Fetched 100 collections on page 683.
# Fetched 100 collections on page 684.
# Fetched 100 collections on page 685.
# Fetched 100 collections on page 686.
# Fetched 100 collections on page 687.
# Fetched 100 collections on page 688.
# Fetched 100 collections on page 689.
# Fetched 100 collections on page 690.
# Fetched 100 collections on page 691.
# Fetched 100 collections on page 692.
# Fetched 100 collections on page 693.
# Fetched 100 collections on page 694.
# Fetched 100 collections on page 695.
# Fetched 100 collections on page 696.
# Fetched 100 collections on page 697.
# Fetched 100 collections on page 698.
# Fetched 100 collections on page 699.
# Fetched 100 collections on page 700.
# Fetched 100 collections on page 701.
# Fetched 100 collections on page 702.
# Fetched 100 collections on page 703.
# Fetched 100 collections on page 704.
# Fetched 100 collections on page 705.
# Fetched 100 collections on page 706.
# Fetched 100 collections on page 707.
# Fetched 100 collections on page 708.
# Fetched 100 collections on page 709.
# Fetched 100 collections on page 710.
# Fetched 100 collections on page 711.
# Fetched 100 collections on page 712.
# Fetched 100 collections on page 713.
# Fetched 100 collections on page 714.
# Fetched 100 collections on page 715.
# Fetched 100 collections on page 716.
# Fetched 100 collections on page 717.
# Fetched 100 collections on page 718.
# Fetched 100 collections on page 719.
# Fetched 100 collections on page 720.
# Fetched 100 collections on page 721.
# Fetched 100 collections on page 722.
# Fetched 100 collections on page 723.
# Fetched 100 collections on page 724.
# Fetched 100 collections on page 725.
# Fetched 100 collections on page 726.
# Fetched 100 collections on page 727.
# Fetched 100 collections on page 728.
# Fetched 100 collections on page 729.
# Fetched 100 collections on page 730.
# Fetched 100 collections on page 731.
# Fetched 100 collections on page 732.
# Fetched 100 collections on page 733.
# Fetched 100 collections on page 734.
# Fetched 100 collections on page 735.
# Fetched 100 collections on page 736.
# Fetched 100 collections on page 737.
# Fetched 100 collections on page 738.
# Fetched 100 collections on page 739.
# Fetched 100 collections on page 740.
# Fetched 100 collections on page 741.
# Fetched 100 collections on page 742.
# Fetched 100 collections on page 743.
# Fetched 100 collections on page 744.
# Fetched 100 collections on page 745.
# Fetched 100 collections on page 746.
# Fetched 100 collections on page 747.
# Fetched 100 collections on page 748.
# Fetched 100 collections on page 749.
# Fetched 100 collections on page 750.
# Fetched 100 collections on page 751.
# Fetched 100 collections on page 752.
# Fetched 100 collections on page 753.
# Fetched 100 collections on page 754.
# Fetched 100 collections on page 755.
# Fetched 100 collections on page 756.
# Fetched 100 collections on page 757.
# Fetched 100 collections on page 758.
# Fetched 100 collections on page 759.
# Fetched 100 collections on page 760.
# Fetched 100 collections on page 761.
# Fetched 100 collections on page 762.
# Fetched 100 collections on page 763.
# Fetched 100 collections on page 764.
# Fetched 100 collections on page 765.
# Fetched 100 collections on page 766.
# Fetched 100 collections on page 767.
# Fetched 100 collections on page 768.
# Fetched 100 collections on page 769.
# Fetched 100 collections on page 770.
# Fetched 100 collections on page 771.
# Fetched 100 collections on page 772.
# Fetched 100 collections on page 773.
# Fetched 100 collections on page 774.
# Fetched 100 collections on page 775.
# Fetched 100 collections on page 776.
# Fetched 100 collections on page 777.
# Fetched 100 collections on page 778.
# Fetched 100 collections on page 779.
# Fetched 100 collections on page 780.
# Fetched 100 collections on page 781.
# Fetched 100 collections on page 782.
# Fetched 100 collections on page 783.
# Fetched 100 collections on page 784.
# Fetched 100 collections on page 785.
# Fetched 100 collections on page 786.
# Fetched 100 collections on page 787.
# Fetched 100 collections on page 788.
# Fetched 100 collections on page 789.
# Fetched 100 collections on page 790.
# Fetched 100 collections on page 791.
# Fetched 100 collections on page 792.
# Fetched 100 collections on page 793.
# Fetched 100 collections on page 794.
# Fetched 100 collections on page 795.
# Fetched 100 collections on page 796.
# Fetched 100 collections on page 797.
# Fetched 100 collections on page 798.
# Fetched 100 collections on page 799.
# Fetched 100 collections on page 800.
# Fetched 100 collections on page 801.
# Fetched 100 collections on page 802.
# Fetched 100 collections on page 803.
# Fetched 100 collections on page 804.
# Fetched 100 collections on page 805.
# Fetched 100 collections on page 806.
# Fetched 100 collections on page 807.
# Fetched 100 collections on page 808.
# Fetched 100 collections on page 809.
# Fetched 100 collections on page 810.
# Fetched 100 collections on page 811.
# Fetched 100 collections on page 812.
# Fetched 100 collections on page 813.
# Fetched 100 collections on page 814.
# Fetched 100 collections on page 815.
# Fetched 100 collections on page 816.
# Fetched 100 collections on page 817.
# Fetched 100 collections on page 818.
# Fetched 100 collections on page 819.
# Fetched 100 collections on page 820.
# Fetched 100 collections on page 821.
# Fetched 100 collections on page 822.
# Fetched 100 collections on page 823.
# Fetched 100 collections on page 824.
# Fetched 100 collections on page 825.
# Fetched 100 collections on page 826.
# Fetched 100 collections on page 827.
# Fetched 100 collections on page 828.
# Fetched 100 collections on page 829.
# Fetched 100 collections on page 830.
# Fetched 100 collections on page 831.
# Fetched 100 collections on page 832.
# Fetched 100 collections on page 833.
# Fetched 100 collections on page 834.
# Fetched 100 collections on page 835.
# Fetched 100 collections on page 836.
# Fetched 100 collections on page 837.
# Fetched 100 collections on page 838.
# Fetched 100 collections on page 839.
# Fetched 100 collections on page 840.
# Fetched 100 collections on page 841.
# Fetched 100 collections on page 842.
# Fetched 100 collections on page 843.
# Fetched 100 collections on page 844.
# Fetched 100 collections on page 845.
# Fetched 100 collections on page 846.
# Fetched 100 collections on page 847.
# Fetched 100 collections on page 848.
# Fetched 100 collections on page 849.
# Fetched 100 collections on page 850.
# Fetched 100 collections on page 851.
# Fetched 100 collections on page 852.
# Fetched 100 collections on page 853.
# Fetched 100 collections on page 854.
# Fetched 100 collections on page 855.
# Fetched 100 collections on page 856.
# Fetched 100 collections on page 857.
# Fetched 100 collections on page 858.
# Fetched 100 collections on page 859.
# Fetched 100 collections on page 860.
# Fetched 100 collections on page 861.
# Fetched 100 collections on page 862.
# Fetched 100 collections on page 863.
# Fetched 100 collections on page 864.
# Fetched 100 collections on page 865.
# Fetched 100 collections on page 866.
# Fetched 100 collections on page 867.
# Fetched 100 collections on page 868.
# Fetched 100 collections on page 869.
# Fetched 100 collections on page 870.
# Fetched 100 collections on page 871.
# Fetched 100 collections on page 872.
# Fetched 100 collections on page 873.
# Fetched 100 collections on page 874.
# Fetched 100 collections on page 875.
# Fetched 100 collections on page 876.
# Fetched 100 collections on page 877.
# Fetched 100 collections on page 878.
# Fetched 100 collections on page 879.
# Fetched 100 collections on page 880.
# Fetched 100 collections on page 881.
# Fetched 100 collections on page 882.
# Fetched 100 collections on page 883.
# Fetched 100 collections on page 884.
# Fetched 100 collections on page 885.
# Fetched 100 collections on page 886.
# Fetched 100 collections on page 887.
# Fetched 100 collections on page 888.
# Fetched 100 collections on page 889.
# Fetched 100 collections on page 890.
# Fetched 100 collections on page 891.
# Fetched 100 collections on page 892.
# Fetched 100 collections on page 893.
# Fetched 100 collections on page 894.
# Fetched 100 collections on page 895.
# Fetched 100 collections on page 896.
# Fetched 100 collections on page 897.
# Fetched 100 collections on page 898.
# Fetched 100 collections on page 899.
# Fetched 100 collections on page 900.
# Fetched 100 collections on page 901.
# Fetched 100 collections on page 902.
# Fetched 100 collections on page 903.
# Fetched 100 collections on page 904.
# Fetched 100 collections on page 905.
# Fetched 100 collections on page 906.
# Fetched 100 collections on page 907.
# Fetched 100 collections on page 908.
# Fetched 100 collections on page 909.
# Fetched 100 collections on page 910.
# Fetched 100 collections on page 911.
# Fetched 100 collections on page 912.
# Fetched 100 collections on page 913.
# Fetched 100 collections on page 914.
# Fetched 100 collections on page 915.
# Fetched 100 collections on page 916.
# Fetched 100 collections on page 917.
# Fetched 100 collections on page 918.
# Fetched 100 collections on page 919.
# Fetched 100 collections on page 920.
# Fetched 100 collections on page 921.
# Fetched 100 collections on page 922.
# Fetched 100 collections on page 923.
# Fetched 100 collections on page 924.
# Fetched 100 collections on page 925.
# Fetched 100 collections on page 926.
# Fetched 100 collections on page 927.
# Fetched 100 collections on page 928.
# Fetched 100 collections on page 929.
# Fetched 100 collections on page 930.
# Fetched 100 collections on page 931.
# Fetched 100 collections on page 932.
# Fetched 100 collections on page 933.
# Fetched 100 collections on page 934.
# Fetched 100 collections on page 935.
# Fetched 100 collections on page 936.
# Fetched 100 collections on page 937.
# Fetched 100 collections on page 938.
# Fetched 100 collections on page 939.
# Fetched 100 collections on page 940.
# Fetched 100 collections on page 941.
# Fetched 100 collections on page 942.
# Fetched 100 collections on page 943.
# Fetched 100 collections on page 944.
# Fetched 100 collections on page 945.
# Fetched 100 collections on page 946.
# Fetched 100 collections on page 947.
# Fetched 100 collections on page 948.
# Fetched 100 collections on page 949.
# Fetched 100 collections on page 950.
# Fetched 100 collections on page 951.
# Fetched 100 collections on page 952.
# Fetched 100 collections on page 953.
# Fetched 100 collections on page 954.
# Fetched 100 collections on page 955.
# Fetched 100 collections on page 956.
# Fetched 100 collections on page 957.
# Fetched 100 collections on page 958.
# Fetched 100 collections on page 959.
# Fetched 100 collections on page 960.
# Fetched 100 collections on page 961.
# Fetched 100 collections on page 962.
# Fetched 100 collections on page 963.
# Fetched 100 collections on page 964.
# Fetched 100 collections on page 965.
# Fetched 100 collections on page 966.
# Fetched 100 collections on page 967.
# Fetched 100 collections on page 968.
# Fetched 100 collections on page 969.
# Fetched 100 collections on page 970.
# Fetched 100 collections on page 971.
# Fetched 100 collections on page 972.
# Fetched 100 collections on page 973.
# Fetched 100 collections on page 974.
# Fetched 100 collections on page 975.
# Fetched 100 collections on page 976.
# Fetched 100 collections on page 977.
# Fetched 100 collections on page 978.
# Fetched 100 collections on page 979.
# Fetched 100 collections on page 980.
# Fetched 100 collections on page 981.
# Fetched 100 collections on page 982.
# Fetched 100 collections on page 983.
# Fetched 100 collections on page 984.
# Fetched 100 collections on page 985.
# Fetched 100 collections on page 986.
# Fetched 100 collections on page 987.
# Fetched 100 collections on page 988.
# Fetched 100 collections on page 989.
# Fetched 100 collections on page 990.
# Fetched 100 collections on page 991.
# Fetched 100 collections on page 992.
# Fetched 100 collections on page 993.
# Fetched 100 collections on page 994.
# Fetched 100 collections on page 995.
# Fetched 100 collections on page 996.
# Fetched 100 collections on page 997.
# Fetched 100 collections on page 998.
# Fetched 100 collections on page 999.
# Fetched 100 collections on page 1000.
# Fetched 100 collections on page 1001.
# Fetched 100 collections on page 1002.
# Fetched 100 collections on page 1003.
# Fetched 100 collections on page 1004.
# Fetched 100 collections on page 1005.
# Fetched 100 collections on page 1006.
# Fetched 100 collections on page 1007.
# Fetched 100 collections on page 1008.
# Fetched 100 collections on page 1009.
# Fetched 100 collections on page 1010.
# Fetched 100 collections on page 1011.
# Fetched 100 collections on page 1012.
# Fetched 100 collections on page 1013.
# Fetched 100 collections on page 1014.
# Fetched 100 collections on page 1015.
# Fetched 100 collections on page 1016.
# Fetched 100 collections on page 1017.
# Fetched 100 collections on page 1018.
# Fetched 100 collections on page 1019.
# Fetched 100 collections on page 1020.
# Fetched 100 collections on page 1021.
# Fetched 100 collections on page 1022.
# Fetched 100 collections on page 1023.
# Fetched 100 collections on page 1024.
# Fetched 100 collections on page 1025.
# Fetched 100 collections on page 1026.
# Fetched 100 collections on page 1027.
# Fetched 100 collections on page 1028.
# Fetched 100 collections on page 1029.
# Fetched 100 collections on page 1030.
# Fetched 100 collections on page 1031.
# Fetched 100 collections on page 1032.
# Fetched 100 collections on page 1033.
# Fetched 100 collections on page 1034.
# Fetched 100 collections on page 1035.
# Fetched 100 collections on page 1036.
# Fetched 100 collections on page 1037.
# Fetched 100 collections on page 1038.
# Fetched 100 collections on page 1039.
# Fetched 100 collections on page 1040.
# Fetched 100 collections on page 1041.
# Fetched 100 collections on page 1042.
# Fetched 100 collections on page 1043.
# Fetched 100 collections on page 1044.
# Fetched 100 collections on page 1045.
# Fetched 100 collections on page 1046.
# Fetched 100 collections on page 1047.
# Fetched 100 collections on page 1048.
# Fetched 100 collections on page 1049.
# Fetched 100 collections on page 1050.
# Fetched 100 collections on page 1051.
# Fetched 100 collections on page 1052.
# Fetched 100 collections on page 1053.
# Fetched 100 collections on page 1054.
# Fetched 100 collections on page 1055.
# Fetched 100 collections on page 1056.
# Fetched 100 collections on page 1057.
# Fetched 100 collections on page 1058.
# Fetched 100 collections on page 1059.
# Fetched 100 collections on page 1060.
# Fetched 100 collections on page 1061.
# Fetched 100 collections on page 1062.
# Fetched 100 collections on page 1063.
# Fetched 100 collections on page 1064.
# Fetched 100 collections on page 1065.
# Fetched 100 collections on page 1066.
# Fetched 100 collections on page 1067.
# Fetched 100 collections on page 1068.
# Fetched 100 collections on page 1069.
# Fetched 100 collections on page 1070.
# Fetched 100 collections on page 1071.
# Fetched 100 collections on page 1072.
# Fetched 100 collections on page 1073.
# Fetched 100 collections on page 1074.
# Fetched 100 collections on page 1075.
# Fetched 100 collections on page 1076.
# Fetched 100 collections on page 1077.
# Fetched 100 collections on page 1078.
# Fetched 100 collections on page 1079.
# Fetched 100 collections on page 1080.
# Fetched 100 collections on page 1081.
# Fetched 100 collections on page 1082.
# Fetched 100 collections on page 1083.
# Fetched 100 collections on page 1084.
# Fetched 100 collections on page 1085.
# Fetched 100 collections on page 1086.
# Fetched 100 collections on page 1087.
# Fetched 100 collections on page 1088.
# Fetched 100 collections on page 1089.
# Fetched 100 collections on page 1090.
# Fetched 100 collections on page 1091.
# Fetched 100 collections on page 1092.
# Fetched 100 collections on page 1093.
# Fetched 100 collections on page 1094.
# Fetched 100 collections on page 1095.
# Fetched 100 collections on page 1096.
# Fetched 100 collections on page 1097.
# Fetched 100 collections on page 1098.
# Fetched 100 collections on page 1099.
# Fetched 100 collections on page 1100.
# Fetched 100 collections on page 1101.
# Fetched 100 collections on page 1102.
# Fetched 100 collections on page 1103.
# Fetched 100 collections on page 1104.
# Fetched 100 collections on page 1105.
# Fetched 100 collections on page 1106.
# Fetched 100 collections on page 1107.
# Fetched 100 collections on page 1108.
# Fetched 100 collections on page 1109.
# Fetched 100 collections on page 1110.
# Fetched 100 collections on page 1111.
# Fetched 100 collections on page 1112.
# Fetched 100 collections on page 1113.
# Fetched 100 collections on page 1114.
# Fetched 100 collections on page 1115.
# Fetched 100 collections on page 1116.
# Fetched 100 collections on page 1117.
# Fetched 100 collections on page 1118.
# Fetched 100 collections on page 1119.
# Fetched 100 collections on page 1120.
# Fetched 100 collections on page 1121.
# Fetched 100 collections on page 1122.
# Fetched 100 collections on page 1123.
# Fetched 100 collections on page 1124.
# Fetched 100 collections on page 1125.
# Fetched 100 collections on page 1126.
# Fetched 100 collections on page 1127.
# Fetched 100 collections on page 1128.
# Fetched 100 collections on page 1129.
# Fetched 100 collections on page 1130.
# Fetched 100 collections on page 1131.
# Fetched 100 collections on page 1132.
# Fetched 100 collections on page 1133.
# Fetched 100 collections on page 1134.
# Fetched 100 collections on page 1135.
# Fetched 100 collections on page 1136.
# Fetched 100 collections on page 1137.
# Fetched 100 collections on page 1138.
# Fetched 100 collections on page 1139.
# Fetched 100 collections on page 1140.
# Fetched 100 collections on page 1141.
# Fetched 100 collections on page 1142.
# Fetched 100 collections on page 1143.
# Fetched 100 collections on page 1144.
# Fetched 100 collections on page 1145.
# Fetched 100 collections on page 1146.
# Fetched 100 collections on page 1147.
# Fetched 100 collections on page 1148.
# Fetched 100 collections on page 1149.
# Fetched 100 collections on page 1150.
# Fetched 100 collections on page 1151.
# Fetched 100 collections on page 1152.
# Fetched 100 collections on page 1153.
# Fetched 100 collections on page 1154.
# Fetched 100 collections on page 1155.
# Fetched 100 collections on page 1156.
# Fetched 100 collections on page 1157.
# Fetched 100 collections on page 1158.
# Fetched 100 collections on page 1159.
# Fetched 100 collections on page 1160.
# Fetched 100 collections on page 1161.
# Fetched 100 collections on page 1162.
# Fetched 100 collections on page 1163.
# Fetched 100 collections on page 1164.
# Fetched 100 collections on page 1165.
# Fetched 100 collections on page 1166.
# Fetched 100 collections on page 1167.
# Fetched 100 collections on page 1168.
# Fetched 100 collections on page 1169.
# Fetched 100 collections on page 1170.
# Fetched 100 collections on page 1171.
# Fetched 100 collections on page 1172.
# Fetched 100 collections on page 1173.
# Fetched 100 collections on page 1174.
# Fetched 100 collections on page 1175.
# Fetched 100 collections on page 1176.
# Fetched 100 collections on page 1177.
# Fetched 100 collections on page 1178.
# Fetched 100 collections on page 1179.
# Fetched 100 collections on page 1180.
# Fetched 100 collections on page 1181.
# Fetched 100 collections on page 1182.
# Fetched 100 collections on page 1183.
# Fetched 100 collections on page 1184.
# Fetched 100 collections on page 1185.
# Fetched 100 collections on page 1186.
# Fetched 100 collections on page 1187.
# Fetched 100 collections on page 1188.
# Fetched 100 collections on page 1189.
# Fetched 100 collections on page 1190.
# Fetched 100 collections on page 1191.
# Fetched 100 collections on page 1192.
# Fetched 100 collections on page 1193.
# Fetched 100 collections on page 1194.
# Fetched 100 collections on page 1195.
# Fetched 100 collections on page 1196.
# Fetched 100 collections on page 1197.
# Fetched 100 collections on page 1198.
# Fetched 100 collections on page 1199.
# Fetched 100 collections on page 1200.
# Fetched 100 collections on page 1201.
# Fetched 100 collections on page 1202.
# Fetched 100 collections on page 1203.
# Fetched 100 collections on page 1204.
# Fetched 100 collections on page 1205.
# Fetched 100 collections on page 1206.
# Fetched 100 collections on page 1207.
# Fetched 100 collections on page 1208.
# Fetched 100 collections on page 1209.
# Fetched 100 collections on page 1210.
# Fetched 100 collections on page 1211.
# Fetched 100 collections on page 1212.
# Fetched 100 collections on page 1213.
# Fetched 100 collections on page 1214.
# Fetched 100 collections on page 1215.
# Fetched 100 collections on page 1216.
# Fetched 100 collections on page 1217.
# Fetched 100 collections on page 1218.
# Fetched 100 collections on page 1219.
# Fetched 100 collections on page 1220.
# Fetched 100 collections on page 1221.
# Fetched 100 collections on page 1222.
# Fetched 100 collections on page 1223.
# Fetched 100 collections on page 1224.
# Fetched 100 collections on page 1225.
# Fetched 100 collections on page 1226.
# Fetched 100 collections on page 1227.
# Fetched 100 collections on page 1228.
# Fetched 100 collections on page 1229.
# Fetched 100 collections on page 1230.
# Fetched 100 collections on page 1231.
# Fetched 100 collections on page 1232.
# Fetched 100 collections on page 1233.
# Fetched 100 collections on page 1234.
# Fetched 100 collections on page 1235.
# Fetched 100 collections on page 1236.
# Fetched 100 collections on page 1237.
# Fetched 100 collections on page 1238.
# Fetched 100 collections on page 1239.
# Fetched 100 collections on page 1240.
# Fetched 100 collections on page 1241.
# Fetched 100 collections on page 1242.
# Fetched 100 collections on page 1243.
# Fetched 100 collections on page 1244.
# Fetched 100 collections on page 1245.
# Fetched 100 collections on page 1246.
# Fetched 100 collections on page 1247.
# Fetched 100 collections on page 1248.
# Fetched 100 collections on page 1249.
# Fetched 100 collections on page 1250.
# Fetched 100 collections on page 1251.
# Fetched 100 collections on page 1252.
# Fetched 100 collections on page 1253.
# Fetched 100 collections on page 1254.
# Fetched 100 collections on page 1255.
# Fetched 100 collections on page 1256.
# Fetched 100 collections on page 1257.
# Fetched 100 collections on page 1258.
# Fetched 100 collections on page 1259.
# Fetched 100 collections on page 1260.
# Fetched 100 collections on page 1261.
# Fetched 100 collections on page 1262.
# Fetched 100 collections on page 1263.
# Fetched 100 collections on page 1264.
# Fetched 100 collections on page 1265.
# Fetched 100 collections on page 1266.
# Fetched 100 collections on page 1267.
# Fetched 100 collections on page 1268.
# Fetched 100 collections on page 1269.
# Fetched 100 collections on page 1270.
# Fetched 100 collections on page 1271.
# Fetched 100 collections on page 1272.
# Fetched 100 collections on page 1273.
# Fetched 100 collections on page 1274.
# Fetched 100 collections on page 1275.
# Fetched 100 collections on page 1276.
# Fetched 100 collections on page 1277.
# Fetched 100 collections on page 1278.
# Fetched 100 collections on page 1279.
# Fetched 100 collections on page 1280.
# Fetched 100 collections on page 1281.
# Fetched 100 collections on page 1282.
# Fetched 100 collections on page 1283.
# Fetched 100 collections on page 1284.
# Fetched 100 collections on page 1285.
# Fetched 100 collections on page 1286.
# Fetched 100 collections on page 1287.
# Fetched 100 collections on page 1288.
# Fetched 100 collections on page 1289.
# Fetched 100 collections on page 1290.
# Fetched 100 collections on page 1291.
# Fetched 100 collections on page 1292.
# ...
# Fetched 100 collections on page 20141.
# Fetched 100 collections on page 20142.
# Fetched 100 collections on page 20143.
# Fetched 100 collections on page 20144.
# Fetched 100 collections on page 20145.
# Fetched 100 collections on page 20146.
# Fetched 100 collections on page 20147.
# Fetched 100 collections on page 20148.
# Fetched 100 collections on page 20149.
# Fetched 100 collections on page 20150.
# Fetched 100 collections on page 20151.
# Fetched 100 collections on page 20152.
# Fetched 100 collections on page 20153.
# Fetched 100 collections on page 20154.
# Fetched 100 collections on page 20155.
# Fetched 100 collections on page 20156.
# Fetched 100 collections on page 20157.
# Fetched 100 collections on page 20158.
# Fetched 100 collections on page 20159.
# Fetched 100 collections on page 20160.
# Fetched 100 collections on page 20161.
# Fetched 100 collections on page 20162.
# Fetched 100 collections on page 20163.
# Fetched 100 collections on page 20164.
# Fetched 100 collections on page 20165.
# Fetched 100 collections on page 20166.
# Fetched 100 collections on page 20167.
# Fetched 100 collections on page 20168.
# Fetched 100 collections on page 20169.
# Fetched 100 collections on page 20170.
# Fetched 100 collections on page 20171.
# Fetched 100 collections on page 20172.
# Fetched 100 collections on page 20173.
# Fetched 100 collections on page 20174.
# Fetched 100 collections on page 20175.
# Fetched 100 collections on page 20176.
# Fetched 100 collections on page 20177.
# Fetched 100 collections on page 20178.
# Fetched 100 collections on page 20179.
# Fetched 100 collections on page 20180.
# Fetched 100 collections on page 20181.
# Fetched 100 collections on page 20182.
# Fetched 100 collections on page 20183.
# Fetched 100 collections on page 20184.
# Fetched 100 collections on page 20185.
# Fetched 100 collections on page 20186.
# Fetched 100 collections on page 20187.
# Fetched 100 collections on page 20188.
# Fetched 100 collections on page 20189.
# Fetched 100 collections on page 20190.
# Fetched 100 collections on page 20191.
# Fetched 100 collections on page 20192.
# Fetched 100 collections on page 20193.
# Fetched 100 collections on page 20194.
# Fetched 100 collections on page 20195.
# Fetched 100 collections on page 20196.
# Fetched 100 collections on page 20197.
# Fetched 100 collections on page 20198.
# Fetched 100 collections on page 20199.
# Fetched 100 collections on page 20200.
# Fetched 100 collections on page 20201.
# Fetched 100 collections on page 20202.
# Fetched 100 collections on page 20203.
# Fetched 100 collections on page 20204.
# Fetched 100 collections on page 20205.
# Fetched 100 collections on page 20206.
# Fetched 100 collections on page 20207.
# Fetched 100 collections on page 20208.
# Fetched 100 collections on page 20209.
# Fetched 100 collections on page 20210.
# Fetched 100 collections on page 20211.
# Fetched 100 collections on page 20212.
# Fetched 100 collections on page 20213.
# Fetched 100 collections on page 20214.
# Fetched 100 collections on page 20215.
# Fetched 100 collections on page 20216.
# Fetched 100 collections on page 20217.
# Fetched 100 collections on page 20218.
# Fetched 100 collections on page 20219.
# Fetched 100 collections on page 20220.
# Fetched 100 collections on page 20221.
# Fetched 100 collections on page 20222.
# Fetched 100 collections on page 20223.
# Fetched 100 collections on page 20224.
# Fetched 100 collections on page 20225.
# Fetched 100 collections on page 20226.
# Fetched 100 collections on page 20227.
# Fetched 100 collections on page 20228.
# Fetched 100 collections on page 20229.
# Fetched 100 collections on page 20230.
# Fetched 100 collections on page 20231.
# Fetched 100 collections on page 20232.
# Fetched 100 collections on page 20233.
# Fetched 100 collections on page 20234.
# Fetched 100 collections on page 20235.
# Fetched 100 collections on page 20236.
# Fetched 100 collections on page 20237.
# Fetched 100 collections on page 20238.
# Fetched 100 collections on page 20239.
# Fetched 100 collections on page 20240.
# Fetched 100 collections on page 20241.
# Fetched 100 collections on page 20242.
# Fetched 100 collections on page 20243.
# Fetched 100 collections on page 20244.
# Fetched 100 collections on page 20245.
# Fetched 100 collections on page 20246.
# Fetched 100 collections on page 20247.
# Fetched 100 collections on page 20248.
# Fetched 100 collections on page 20249.
# Fetched 100 collections on page 20250.
# Fetched 100 collections on page 20251.
# Fetched 100 collections on page 20252.
# Fetched 100 collections on page 20253.
# Fetched 100 collections on page 20254.
# Fetched 100 collections on page 20255.
# Fetched 100 collections on page 20256.
# Fetched 100 collections on page 20257.
# Fetched 100 collections on page 20258.
# Fetched 100 collections on page 20259.
# Fetched 100 collections on page 20260.
# Fetched 100 collections on page 20261.
# Fetched 100 collections on page 20262.
# Fetched 100 collections on page 20263.
# Fetched 100 collections on page 20264.
# Fetched 100 collections on page 20265.
# Fetched 100 collections on page 20266.
# Fetched 100 collections on page 20267.
# Fetched 100 collections on page 20268.
# Fetched 100 collections on page 20269.
# Fetched 100 collections on page 20270.
# Fetched 100 collections on page 20271.
# Fetched 100 collections on page 20272.
# Fetched 100 collections on page 20273.
# Fetched 100 collections on page 20274.
# Fetched 100 collections on page 20275.
# Fetched 100 collections on page 20276.
# Fetched 100 collections on page 20277.
# Fetched 100 collections on page 20278.
# Fetched 100 collections on page 20279.
# Fetched 100 collections on page 20280.
# Fetched 100 collections on page 20281.
# Fetched 100 collections on page 20282.
# Fetched 100 collections on page 20283.
# Fetched 100 collections on page 20284.
# Fetched 100 collections on page 20285.
# Fetched 100 collections on page 20286.
# Fetched 100 collections on page 20287.
# Fetched 100 collections on page 20288.
# Fetched 100 collections on page 20289.
# Fetched 100 collections on page 20290.
# Fetched 100 collections on page 20291.
# Fetched 100 collections on page 20292.
# Fetched 100 collections on page 20293.
# Fetched 100 collections on page 20294.
# Fetched 100 collections on page 20295.
# Fetched 100 collections on page 20296.
# Fetched 100 collections on page 20297.
# Fetched 100 collections on page 20298.
# Fetched 100 collections on page 20299.
# Fetched 100 collections on page 20300.
# Fetched 100 collections on page 20301.
# Fetched 100 collections on page 20302.
# Fetched 100 collections on page 20303.
# Fetched 100 collections on page 20304.
# Fetched 100 collections on page 20305.
# Fetched 100 collections on page 20306.
# Fetched 100 collections on page 20307.
# Fetched 100 collections on page 20308.
# Fetched 100 collections on page 20309.
# Fetched 100 collections on page 20310.
# Fetched 100 collections on page 20311.
# Fetched 100 collections on page 20312.
# Fetched 100 collections on page 20313.
# Fetched 100 collections on page 20314.
# Fetched 100 collections on page 20315.
# Fetched 100 collections on page 20316.
# Fetched 100 collections on page 20317.
# Fetched 100 collections on page 20318.
# Fetched 100 collections on page 20319.
# Fetched 100 collections on page 20320.
# Fetched 100 collections on page 20321.
# Fetched 100 collections on page 20322.
# Fetched 100 collections on page 20323.
# Fetched 100 collections on page 20324.
# Fetched 100 collections on page 20325.
# Fetched 100 collections on page 20326.
# Fetched 100 collections on page 20327.
# Fetched 100 collections on page 20328.
# Fetched 100 collections on page 20329.
# Fetched 100 collections on page 20330.
# Fetched 100 collections on page 20331.
# Fetched 100 collections on page 20332.
# Fetched 100 collections on page 20333.
# Fetched 100 collections on page 20334.
# Fetched 100 collections on page 20335.
# Fetched 100 collections on page 20336.
# Fetched 100 collections on page 20337.
# Fetched 100 collections on page 20338.
# Fetched 100 collections on page 20339.
# Fetched 100 collections on page 20340.
# Fetched 100 collections on page 20341.
# Fetched 100 collections on page 20342.
# Fetched 100 collections on page 20343.
# Fetched 100 collections on page 20344.
# Fetched 100 collections on page 20345.
# Fetched 100 collections on page 20346.
# Fetched 100 collections on page 20347.
# Fetched 100 collections on page 20348.
# Fetched 100 collections on page 20349.
# Fetched 100 collections on page 20350.
# Fetched 100 collections on page 20351.
# Fetched 100 collections on page 20352.
# Fetched 100 collections on page 20353.
# Fetched 100 collections on page 20354.
# Fetched 100 collections on page 20355.
# Fetched 100 collections on page 20356.
# Fetched 100 collections on page 20357.
# Fetched 100 collections on page 20358.
# Fetched 100 collections on page 20359.
# Fetched 100 collections on page 20360.
# Fetched 100 collections on page 20361.
# Fetched 100 collections on page 20362.
# Fetched 100 collections on page 20363.
# Fetched 100 collections on page 20364.
# Fetched 100 collections on page 20365.
# Fetched 100 collections on page 20366.
# Fetched 100 collections on page 20367.
# Fetched 100 collections on page 20368.
# Fetched 100 collections on page 20369.
# Fetched 100 collections on page 20370.
# Fetched 100 collections on page 20371.
# Fetched 100 collections on page 20372.
# Fetched 100 collections on page 20373.
# Fetched 100 collections on page 20374.
# Fetched 100 collections on page 20375.
# Fetched 100 collections on page 20376.
# Fetched 100 collections on page 20377.
# Fetched 100 collections on page 20378.
# Fetched 100 collections on page 20379.
# Fetched 100 collections on page 20380.
# Fetched 100 collections on page 20381.
# Fetched 100 collections on page 20382.
# Fetched 100 collections on page 20383.
# Fetched 100 collections on page 20384.
# Fetched 100 collections on page 20385.
# Fetched 100 collections on page 20386.
# Fetched 100 collections on page 20387.
# Fetched 100 collections on page 20388.
# Fetched 100 collections on page 20389.
# Fetched 100 collections on page 20390.
# Fetched 100 collections on page 20391.
# Fetched 100 collections on page 20392.
# Fetched 100 collections on page 20393.
# Fetched 100 collections on page 20394.
# Fetched 100 collections on page 20395.
# Fetched 100 collections on page 20396.
# Fetched 100 collections on page 20397.
# Fetched 100 collections on page 20398.
# Fetched 100 collections on page 20399.
# Fetched 100 collections on page 20400.
# Fetched 100 collections on page 20401.
# Fetched 100 collections on page 20402.
# Fetched 100 collections on page 20403.
# Fetched 100 collections on page 20404.
# Fetched 100 collections on page 20405.
# Fetched 100 collections on page 20406.
# Fetched 100 collections on page 20407.
# Fetched 100 collections on page 20408.
# Fetched 100 collections on page 20409.
# Fetched 100 collections on page 20410.
# Fetched 100 collections on page 20411.
# Fetched 100 collections on page 20412.
# Fetched 100 collections on page 20413.
# Fetched 100 collections on page 20414.
# Fetched 100 collections on page 20415.
# Fetched 100 collections on page 20416.
# Fetched 100 collections on page 20417.
# Fetched 100 collections on page 20418.
# Fetched 100 collections on page 20419.
# Fetched 100 collections on page 20420.
# Fetched 100 collections on page 20421.
# Fetched 100 collections on page 20422.
# Fetched 100 collections on page 20423.
# Fetched 100 collections on page 20424.
# Fetched 100 collections on page 20425.
# Fetched 100 collections on page 20426.
# Fetched 100 collections on page 20427.
# Fetched 100 collections on page 20428.
# Fetched 100 collections on page 20429.
# Fetched 100 collections on page 20430.
# Fetched 100 collections on page 20431.
# Fetched 100 collections on page 20432.
# Fetched 100 collections on page 20433.
# Fetched 100 collections on page 20434.
# Fetched 100 collections on page 20435.
# Fetched 100 collections on page 20436.
# Fetched 100 collections on page 20437.
# Fetched 100 collections on page 20438.
# Fetched 100 collections on page 20439.
# Fetched 100 collections on page 20440.
# Fetched 100 collections on page 20441.
# Fetched 100 collections on page 20442.
# Fetched 100 collections on page 20443.
# Fetched 100 collections on page 20444.
# Fetched 100 collections on page 20445.
# Fetched 100 collections on page 20446.
# Fetched 100 collections on page 20447.
# Fetched 100 collections on page 20448.
# Fetched 100 collections on page 20449.
# Fetched 100 collections on page 20450.
# Fetched 100 collections on page 20451.
# Fetched 100 collections on page 20452.
# Fetched 100 collections on page 20453.
# Fetched 100 collections on page 20454.
# Fetched 100 collections on page 20455.
# Fetched 100 collections on page 20456.
# Fetched 100 collections on page 20457.
# Fetched 100 collections on page 20458.
# Fetched 100 collections on page 20459.
# Fetched 100 collections on page 20460.
# Fetched 100 collections on page 20461.
# Fetched 100 collections on page 20462.
# Fetched 100 collections on page 20463.
# Fetched 100 collections on page 20464.
# Request exception: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Attempt 1. Retrying...
# Fetched 100 collections on page 20465.
# Fetched 100 collections on page 20466.
# Fetched 100 collections on page 20467.
# Fetched 100 collections on page 20468.
# Fetched 100 collections on page 20469.
# Fetched 100 collections on page 20470.
# Fetched 100 collections on page 20471.
# Fetched 100 collections on page 20472.
# Fetched 100 collections on page 20473.
# Fetched 100 collections on page 20474.
# Fetched 100 collections on page 20475.
# Fetched 100 collections on page 20476.
# Fetched 100 collections on page 20477.
# Fetched 100 collections on page 20478.
# Fetched 100 collections on page 20479.
# Fetched 100 collections on page 20480.
# Fetched 100 collections on page 20481.
# Fetched 100 collections on page 20482.
# Fetched 100 collections on page 20483.
# Fetched 100 collections on page 20484.
# Fetched 100 collections on page 20485.
# Fetched 100 collections on page 20486.
# Fetched 100 collections on page 20487.
# Fetched 100 collections on page 20488.
# Fetched 100 collections on page 20489.
# Fetched 100 collections on page 20490.
# Fetched 100 collections on page 20491.
# Fetched 100 collections on page 20492.
# Fetched 100 collections on page 20493.
# Fetched 100 collections on page 20494.
# Fetched 100 collections on page 20495.
# Fetched 100 collections on page 20496.
# Fetched 100 collections on page 20497.
# Fetched 100 collections on page 20498.
# Fetched 100 collections on page 20499.
# Fetched 100 collections on page 20500.
# Fetched 100 collections on page 20501.
# Fetched 100 collections on page 20502.
# Fetched 100 collections on page 20503.
# Fetched 100 collections on page 20504.
# Fetched 100 collections on page 20505.
# Fetched 100 collections on page 20506.
# Fetched 100 collections on page 20507.
# Fetched 100 collections on page 20508.
# Fetched 100 collections on page 20509.
# Fetched 100 collections on page 20510.
# Fetched 100 collections on page 20511.
# Fetched 100 collections on page 20512.
# Fetched 100 collections on page 20513.
# Fetched 100 collections on page 20514.
# Fetched 100 collections on page 20515.
# Fetched 100 collections on page 20516.
# Fetched 100 collections on page 20517.
# Fetched 100 collections on page 20518.
# Fetched 100 collections on page 20519.
# Fetched 100 collections on page 20520.
# Fetched 100 collections on page 20521.
# Fetched 100 collections on page 20522.
# Fetched 100 collections on page 20523.
# Fetched 100 collections on page 20524.
# Fetched 100 collections on page 20525.
# Fetched 100 collections on page 20526.
# Fetched 100 collections on page 20527.
# Fetched 100 collections on page 20528.
# Fetched 100 collections on page 20529.
# Fetched 100 collections on page 20530.
# Fetched 100 collections on page 20531.
# Fetched 100 collections on page 20532.
# Fetched 100 collections on page 20533.
# Fetched 100 collections on page 20534.
# Fetched 100 collections on page 20535.
# Fetched 100 collections on page 20536.
# Fetched 100 collections on page 20537.
# Fetched 100 collections on page 20538.
# Fetched 100 collections on page 20539.
# Fetched 100 collections on page 20540.
# Fetched 100 collections on page 20541.
# Fetched 100 collections on page 20542.
# Fetched 100 collections on page 20543.
# Fetched 100 collections on page 20544.
# Fetched 100 collections on page 20545.

# %% [markdown]
# Supply and Fees

# %%
def safe_get(url, headers, max_retries=5):
    for attempt in range(max_retries):
        try:
            response = requests.get(url, headers=headers, timeout=15)
            
            if response.status_code == 200:
                return response.json()
            elif 500 <= response.status_code < 600:
                print(f"Server error {response.status_code}, attempt {attempt+1}. Retrying...")
                time.sleep(2 ** attempt)  # exponential backoff
            else:
                # 4xx or other error => skip
                print(f"Error {response.status_code} fetching {url}: {response.text}")
                return None
        except requests.exceptions.RequestException as e:
            print(f"RequestException on attempt {attempt+1}: {e}")
            time.sleep(2 ** attempt)

    print(f"Failed after {max_retries} attempts: {url}")
    return None

def add_missing_columns(conn):
    """
    Adds the new columns to the existing 'collections' table.
    If the columns already exist, SQLite will ignore the error
    (or you can wrap in try/except).
    """
    cursor = conn.cursor()
    
    # For each column, attempt an ALTER TABLE statement
    # (If the column exists, this will error, so you may want try/except)
    alter_statements = [
        "ALTER TABLE collections ADD COLUMN total_supply INTEGER",
        "ALTER TABLE collections ADD COLUMN created_date TEXT",
        "ALTER TABLE collections ADD COLUMN opensea_fee REAL",
        "ALTER TABLE collections ADD COLUMN opensea_fee_mandatory INTEGER",
        "ALTER TABLE collections ADD COLUMN royalty REAL",
        "ALTER TABLE collections ADD COLUMN royalty_mandatory INTEGER"
    ]
    
    for stmt in alter_statements:
        try:
            cursor.execute(stmt)
            print(f"Executed: {stmt}")
        except sqlite3.OperationalError as e:
            # Likely the column already exists
            print(f"Skipping: {stmt} => {e}")
    
    conn.commit()

def update_opensea_details(conn, api_key):
    """
    Reads 'id' and 'collection_slug' from 'collections' table
    in 'collections_opensea.db', calls
    https://api.opensea.io/api/v2/collections/{collection_slug}
    then updates the record with the new fields:
      - total_supply
      - created_date
      - opensea_fee
      - opensea_fee_mandatory
      - royalty
      - royalty_mandatory
    """
    cursor = conn.cursor()
    
    # fetch all slugs
    cursor.execute("SELECT id, collection_slug FROM collections")
    rows = cursor.fetchall()
    
    headers = {
        "accept": "application/json",
        "x-api-key": api_key
    }
    
    update_sql = """
    UPDATE collections
    SET total_supply = ?,
        created_date = ?,
        opensea_fee = ?,
        opensea_fee_mandatory = ?,
        royalty = ?,
        royalty_mandatory = ?
    WHERE id = ?
    """
    
    count = 0
    for (row_id, slug) in rows:
        if not slug:
            # If there's no slug, skip
            continue
        
        url = f"https://api.opensea.io/api/v2/collections/{slug}"
        
        data = safe_get(url, headers)
        if not data:
            # Could not retrieve or error
            continue
        
        # parse the fields
        # top-level object is the 'collection' key from the JSON
        collection_obj = data  # might be 'data["collection"]' but the sample shows root-level keys
        # Check if 'collection' is the actual root or there's a nested?
        # If the API returns: { "collection": {...} }, we do:
        if "collection" in data and isinstance(data["collection"], dict):
            collection_obj = data["collection"]
        
        # total_supply
        total_supply = collection_obj.get("total_supply", 0)
        
        # created_date
        created_date = collection_obj.get("created_date", "")
        
        # fees array
        fees = collection_obj.get("fees", [])
        
        opensea_fee = 0.0
        opensea_fee_mandatory = 0
        royalty = 0.0
        royalty_mandatory = 0
        
        if len(fees) >= 1:
            opensea_fee = float(fees[0].get("fee", 0.0))
            opensea_fee_mandatory = 1 if fees[0].get("required", False) else 0
        
        if len(fees) >= 2:
            royalty = float(fees[1].get("fee", 0.0))
            royalty_mandatory = 1 if fees[1].get("required", False) else 0
        
        # Now update the row
        cursor.execute(update_sql, (
            total_supply,
            created_date,
            opensea_fee,
            opensea_fee_mandatory,
            royalty,
            royalty_mandatory,
            row_id
        ))
        count += 1
        
        # optional: slow down to avoid rate-limiting
        # time.sleep(0.1)
    
    conn.commit()
    print(f"Updated {count} rows with new data.")


def main():
    api_key = "your_key"
    db_path = "data/collections_opensea.db"
    
    conn = sqlite3.connect(db_path)
    
    # Add columns if needed
    add_missing_columns(conn)
    
    # Update each row with extended info
    update_opensea_details(conn, api_key)
    
    conn.close()
    print("Done.")

# %%
if __name__ == "__main__":
    main()
# Out:
# Skipping: ALTER TABLE collections ADD COLUMN total_supply INTEGER => duplicate column name: total_supply
# Skipping: ALTER TABLE collections ADD COLUMN created_date TEXT => duplicate column name: created_date
# Skipping: ALTER TABLE collections ADD COLUMN opensea_fee REAL => duplicate column name: opensea_fee
# Skipping: ALTER TABLE collections ADD COLUMN opensea_fee_mandatory INTEGER => duplicate column name: opensea_fee_mandatory
# Skipping: ALTER TABLE collections ADD COLUMN royalty REAL => duplicate column name: royalty
# Skipping: ALTER TABLE collections ADD COLUMN royalty_mandatory INTEGER => duplicate column name: royalty_mandatory
# Error 400 fetching https://api.opensea.io/api/v2/collections/world-coins-2: {"errors":["Collection world-coins-2 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/lord-of-toil-night-1: {"errors":["Collection lord-of-toil-night-1 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/cl-01: {"errors":["Collection cl-01 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/modern-era-2: {"errors":["Collection modern-era-2 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/places-colors: {"errors":["Collection places-colors not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/alien-bonk-5: {"errors":["Collection alien-bonk-5 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/unihorse-5: {"errors":["Collection unihorse-5 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/alien-bonk-4: {"errors":["Collection alien-bonk-4 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/alien-bonk-3: {"errors":["Collection alien-bonk-3 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/alien-bonk-2: {"errors":["Collection alien-bonk-2 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/alien-bonk-1: {"errors":["Collection alien-bonk-1 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/phagyos2: {"errors":["Collection phagyos2 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/i-scribbled-0-3: {"errors":["Collection i-scribbled-0-3 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/lyco-1: {"errors":["Collection lyco-1 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/foxycat-1: {"errors":["Collection foxycat-1 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/southmaniac: {"errors":["Collection southmaniac not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/the-museum-of-moving-art-1: {"errors":["Collection the-museum-of-moving-art-1 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/solana-qr: {"errors":["Collection solana-qr not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/cetus-4: {"errors":["Collection cetus-4 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/ether-guardians-2: {"errors":["Collection ether-guardians-2 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/el-brillo-de-luna-1: {"errors":["Collection el-brillo-de-luna-1 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/ether-guardians-1: {"errors":["Collection ether-guardians-1 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/el-brillo-de-luna: {"errors":["Collection el-brillo-de-luna not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/unimix-collection: {"errors":["Collection unimix-collection not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/unique-collection-37: {"errors":["Collection unique-collection-37 not found"]}
# RequestException on attempt 1: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# RequestException on attempt 2: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# RequestException on attempt 3: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# RequestException on attempt 4: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# RequestException on attempt 5: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# Failed after 5 attempts: https://api.opensea.io/api/v2/collections/zora-posts-25943
# Error 400 fetching https://api.opensea.io/api/v2/collections/bair-market-traders: {"errors":["Collection bair-market-traders not found"]}
# RequestException on attempt 1: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# RequestException on attempt 2: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# RequestException on attempt 3: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# RequestException on attempt 4: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# RequestException on attempt 5: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# Failed after 5 attempts: https://api.opensea.io/api/v2/collections/knockout-member
# Error 400 fetching https://api.opensea.io/api/v2/collections/alien-bonk: {"errors":["Collection alien-bonk not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/series-february-12-2025: {"errors":["Collection series-february-12-2025 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/ancient-modern-2: {"errors":["Collection ancient-modern-2 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/ancient-modern-1: {"errors":["Collection ancient-modern-1 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/babyglitchcity: {"errors":["Collection babyglitchcity not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/catsbe-1: {"errors":["Collection catsbe-1 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/tickets-57: {"errors":["Collection tickets-57 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/mons-duck: {"errors":["Collection mons-duck not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections
HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# RequestException on attempt 5: HTTPSConnectionPool(host='api.opensea.io', port=443): Read timed out. (read timeout=15)
# Failed after 5 attempts: https://api.opensea.io/api/v2/collections/gisvitoscorcese-member
# Error 400 fetching https://api.opensea.io/api/v2/collections/peng-dy: {"errors":["Collection peng-dy not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/mechadroids-3: {"errors":["Collection mechadroids-3 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/abstract-wingy-3: {"errors":["Collection abstract-wingy-3 not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/fusion-gaming: {"errors":["Collection fusion-gaming not found"]}
# Error 400 fetching https://api.opensea.io/api/v2/collections/bzenerszun: {"errors":["Collection bzenerszun not found"]}
# Error 429 fetching https://api.opensea.io/api/v2/collections/realberahaw: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/eth-10-10-3-2025-c-3200: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/court-21: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/nano-art-copy: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-otter-club-base-078: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-orca-club-base-076: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 400 fetching https://api.opensea.io/api/v2/collections/deforumed-1: {"errors":["Collection deforumed-1 not found"]}
# Error 429 fetching https://api.opensea.io/api/v2/collections/ninjafrogcoin-pixels: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/rainforest-haven-member: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/asdf-199: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lens-collect-profile-194665-publication-38: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lens-collect-profile-193819-publication-37: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/thug-panda-in-cuty-with-ganster-look: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-koala-club-base-061: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-kiwi-club-base-060: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-kinkajou-club-base-059: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lens-collect-profile-497945-publication-984: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/ortest: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/zora-posts-25678: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/cosmic-serenity-5: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-gharial-club-base-044: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lens-collect-profile-195148-publication-52: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lens-collect-profile-185590-publication-37: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/jalesfeva-2: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/rotixu-member: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-dugong-club-base-035: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/dfgetrdgg-9: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/fddfgwert-10: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/dfgetrdgg-8: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/rise-and-shine-member: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/cryptobtc-member: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lens-collect-profile-636551-publication-199: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/kozyatun: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lens-collect-profile-196053-publication-51: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-chimpanzee-club-base-024: {"detail":"Request was throttled. Expected available in 60 seconds."}
# Error 429 fetching https://api.opensea.io/api/v2/collections/aris-airdrop-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/republiqe-paris-2025: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lens-collect-profile-135516-publication-5306: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/sol-4-10-3-2025-c-250: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/dsa-119: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/axiememento-1: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-chicken-club-base-023: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/teste-cel: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/awesome-52: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-cheetah-club-base-022: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/geometricharmony-69: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/0xe3202764538cc71dbde70e66c8c9bcc41798cbf6: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/robot-cat-19: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lens-collect-profile-592962-publication-104: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/vbnfghrt-9: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/dgfertsf-9: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/back-to-the-mushroom: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/oihoihh: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/gfdcbvty-9: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/happy-cat-club-base-021: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/modest-horn-players-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/high-speed-travel: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/fdgretfgh-7: {"detail":"Request was throttled.","id":"1KQIYV"}
# ...
# Error 429 fetching https://api.opensea.io/api/v2/collections/ape-diamond-1: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/this-is-halloween-2: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/ape-inscriptions: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/monkey-war-chain-s: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/gnpwksve: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/thomasfa-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/pov-edition-one: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/blinkbananas: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/apetestmintsss: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/popape-og-nft: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/scary-but-beautiful-membership-collectible: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/the-tortoise-and-the-hare-balancing-ux-scalability: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/etrfubp: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/party-memberships-webchain-3: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/axjwvede: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/hayivoy-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/mochi-circle-12: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/gdsdf-1: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/irrbvqok: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/udejnz: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/intense-crown-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/turnermuf-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/all-star-painting-ozark: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lords-of-fud-1: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/naotfrg: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/trumpledore-3: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/apeplants: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/vkwhravbs: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/ape-chain-tunes-2: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/party-memberships-xtreme-tiger: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/chi-33: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/gsekbh-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/trumpledore-2: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/trumpledore-1: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/hlopmdwkyk: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/baby-doll-8: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/cwqgcvpen: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/communities-14: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/pixelcat23: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/qdyzs: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/uxzggd: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/trumpledore: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/kymsijjac: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/base-grandpa-s-9: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/omijivi-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/uzlvfrrq: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/bare-bears-nft: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/apelantia-1: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/rumyoddfm: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/not-apes-1: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/jkaly: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/pepe-1058: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/ajpksxcvv: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/badbumf-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/mochi-circle-11: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/doge-race-100: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/no-dinos-1: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/party-memberships-jazzy-dragon: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/lomira: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/apesea-9: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/yeetards-3: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/heavy-respected: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/gluteus-maximus-1: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/blockapex-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/panic-21: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/coupled-12: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/didutomaj-member: {"detail":"Request was throttled.","id":"1KQIYV"}
# Error 429 fetching https://api.opensea.io/api/v2/collections/waghis-129: {"detail":"Request was throttled.","id":"1KQIYV"}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[2], line 158, in main()
#     155 add_missing_columns(conn)
#     157 # Update each row with extended info
# --> 158 update_opensea_details(conn, api_key)
#     160 conn.close()
#     161 print("Done.")
#
# Cell In[2], line 94, in update_opensea_details(conn, api_key)
#      90     continue
#      92 url = f"https://api.opensea.io/api/v2/collections/{slug}"
# ---> 94 data = safe_get(url, headers)
#      95 if not data:
#      96     # Could not retrieve or error
#      97     continue
#
# Cell In[2], line 4, in safe_get(url, headers, max_retries)
#       2 for attempt in range(max_retries):
#       3     try:
# ----> 4         response = requests.get(url, headers=headers, timeout=15)
#       6         if response.status_code == 200:
#       7             return response.json()
#
# File c:\Users\Sören Schlißke\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Sören Schlißke\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Sören Schlißke\anaconda3\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Sören Schlißke\anaconda3\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Sören Schlißke\anaconda3\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\Sören Schlißke\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\Sören Schlißke\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\Sören Schlißke\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\Users\Sören Schlißke\anaconda3\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\Sören Schlißke\anaconda3\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Sören Schlißke\anaconda3\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Sören Schlißke\anaconda3\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\Sören Schlißke\anaconda3\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Sören Schlißke\anaconda3\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Rarible

# %%
import requests
import time
import sqlite3

def create_table_if_not_exists(conn):
    """
    Create a 'rarible_collections' table if it does not exist.
    You can adjust the columns as you see fit.
    """
    create_sql = """
    CREATE TABLE IF NOT EXISTS rarible_collections (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        collection_id TEXT,
        blockchain TEXT,
        structure TEXT,
        collection_type TEXT,
        status TEXT,
        name TEXT,
        symbol TEXT,
        owner TEXT,
        meta_name TEXT,
        meta_description TEXT,
        meta_created_at TEXT,
        spam_score INTEGER,
        is_shared INTEGER,
        is_self INTEGER,
        updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
    """
    conn.execute(create_sql)
    conn.commit()


def insert_collections(conn, collections):
    """
    Insert a batch of collections into the 'rarible_collections' table.
    """
    insert_sql = """
    INSERT INTO rarible_collections (
        collection_id,
        blockchain,
        structure,
        collection_type,
        status,
        name,
        symbol,
        owner,
        meta_name,
        meta_description,
        meta_created_at,
        spam_score,
        is_shared,
        is_self
    ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """

    records = []
    for c in collections:
        collection_id = c.get("id", "")
        blockchain = c.get("blockchain", "")
        structure = c.get("structure", "")
        collection_type = c.get("type", "")
        status = c.get("status", "")
        name = c.get("name", "")
        symbol = c.get("symbol", "")
        owner = c.get("owner", "")
        
        meta = c.get("meta", {})
        meta_name = meta.get("name", "")
        meta_description = meta.get("description", "")
        meta_created_at = meta.get("createdAt", "")
        
        spam_score = c.get("spamScore", 0)
        is_shared = 1 if c.get("shared", False) else 0
        is_self_value = 1 if c.get("self", False) else 0
        
        row = (
            collection_id,
            blockchain,
            structure,
            collection_type,
            status,
            name,
            symbol,
            owner,
            meta_name,
            meta_description,
            meta_created_at,
            spam_score,
            is_shared,
            is_self_value
        )
        records.append(row)

    conn.executemany(insert_sql, records)
    conn.commit()


def fetch_all_rarible_collections(api_key, max_pages=None):
    """
    Fetch as many collections as possible from Rarible's /v0.1/collections/all endpoint
    using continuation-based pagination. Each page is saved immediately into a SQLite
    database ('collections_rarible.db') so that data isn't lost if the script is interrupted.

    :param api_key: Your Rarible API key (string).
    :param max_pages: Optional integer limit on pages to fetch. If None, continue until no continuation.
    """
    base_url = "https://api.rarible.org/v0.1/collections/all"

    headers = {
        "accept": "application/json",
        "X-API-KEY": api_key
    }

    # Connect to the local SQLite database
    conn = sqlite3.connect("data/collections_rarible.db")
    create_table_if_not_exists(conn)

    continuation = None
    page_count = 0

    while True:
        params = {
            "size": 100  # up to 100 items per page (you can adjust as needed)
        }
        if continuation:
            params["continuation"] = continuation

        try:
            response = requests.get(base_url, headers=headers, params=params)
        except requests.exceptions.RequestException as e:
            print(f"Request exception: {e}. Stopping.")
            break

        if response.status_code != 200:
            print(f"Error code {response.status_code}: {response.text}")
            break

        data = response.json()

        # Extract the collections from this page
        collections = data.get("collections", [])
        if not collections:
            print("No collections returned. Stopping.")
            break

        # Insert them into the DB
        insert_collections(conn, collections)

        page_count += 1
        print(f"Fetched {len(collections)} collections on page {page_count}.")

        # Check if we have a next page (continuation token)
        continuation = data.get("continuation")
        if not continuation:
            print("No more 'continuation' token, finished all pages.")
            break

        # If you have a maximum page limit
        if max_pages and page_count >= max_pages:
            print(f"Reached max_pages={max_pages}. Stopping.")
            break

        # OPTIONAL: small delay to avoid hitting rate limits or server overload
        # time.sleep(0.1)

    conn.close()
    print(f"Finished. Pages fetched: {page_count}")

# %%
if __name__ == "__main__":
    # Replace with your real Rarible API key
    RARIBLE_API_KEY = "your_key"

    # Run the fetch function
    # For unlimited pages, set max_pages=None, or pick a limit like 100:
    fetch_all_rarible_collections(RARIBLE_API_KEY, max_pages=None)
# Out:
# Fetched 100 collections on page 1.
# Fetched 100 collections on page 2.
# Fetched 100 collections on page 3.
# Fetched 100 collections on page 4.
# Fetched 100 collections on page 5.
# Fetched 100 collections on page 6.
# Fetched 100 collections on page 7.
# Fetched 100 collections on page 8.
# Fetched 100 collections on page 9.
# Fetched 100 collections on page 10.
# Fetched 100 collections on page 11.
# Fetched 100 collections on page 12.
# Fetched 100 collections on page 13.
# Fetched 100 collections on page 14.
# Fetched 100 collections on page 15.
# Fetched 100 collections on page 16.
# Fetched 100 collections on page 17.
# Fetched 100 collections on page 18.
# Fetched 100 collections on page 19.
# Fetched 100 collections on page 20.
# Fetched 100 collections on page 21.
# Fetched 100 collections on page 22.
# Fetched 100 collections on page 23.
# Fetched 100 collections on page 24.
# Fetched 100 collections on page 25.
# Fetched 100 collections on page 26.
# Fetched 100 collections on page 27.
# Fetched 100 collections on page 28.
# Fetched 100 collections on page 29.
# Fetched 100 collections on page 30.
# Fetched 100 collections on page 31.
# Fetched 100 collections on page 32.
# Fetched 100 collections on page 33.
# Fetched 100 collections on page 34.
# Fetched 100 collections on page 35.
# Fetched 100 collections on page 36.
# Fetched 100 collections on page 37.
# Fetched 100 collections on page 38.
# Fetched 100 collections on page 39.
# Fetched 100 collections on page 40.
# Fetched 100 collections on page 41.
# Fetched 100 collections on page 42.
# Fetched 100 collections on page 43.
# Fetched 100 collections on page 44.
# Fetched 100 collections on page 45.
# Fetched 100 collections on page 46.
# Fetched 100 collections on page 47.
# Fetched 100 collections on page 48.
# Fetched 100 collections on page 49.
# Fetched 100 collections on page 50.
# Fetched 100 collections on page 51.
# Fetched 100 collections on page 52.
# Fetched 100 collections on page 53.
# Fetched 100 collections on page 54.
# Fetched 100 collections on page 55.
# Fetched 100 collections on page 56.
# Fetched 100 collections on page 57.
# Fetched 100 collections on page 58.
# Fetched 100 collections on page 59.
# Fetched 100 collections on page 60.
# Fetched 100 collections on page 61.
# Fetched 100 collections on page 62.
# Fetched 100 collections on page 63.
# Fetched 100 collections on page 64.
# Fetched 100 collections on page 65.
# Fetched 100 collections on page 66.
# Fetched 100 collections on page 67.
# Fetched 100 collections on page 68.
# Fetched 100 collections on page 69.
# Fetched 100 collections on page 70.
# Fetched 100 collections on page 71.
# Fetched 100 collections on page 72.
# Fetched 100 collections on page 73.
# Fetched 100 collections on page 74.
# Fetched 100 collections on page 75.
# Fetched 100 collections on page 76.
# Fetched 100 collections on page 77.
# Fetched 100 collections on page 78.
# Fetched 100 collections on page 79.
# Fetched 100 collections on page 80.
# Fetched 100 collections on page 81.
# Fetched 100 collections on page 82.
# Fetched 100 collections on page 83.
# Fetched 100 collections on page 84.
# Fetched 100 collections on page 85.
# Fetched 100 collections on page 86.
# Fetched 100 collections on page 87.
# Fetched 100 collections on page 88.
# Fetched 100 collections on page 89.
# Fetched 100 collections on page 90.
# Fetched 100 collections on page 91.
# Fetched 100 collections on page 92.
# Fetched 100 collections on page 93.
# Fetched 100 collections on page 94.
# Fetched 100 collections on page 95.
# Fetched 100 collections on page 96.
# Fetched 100 collections on page 97.
# Fetched 100 collections on page 98.
# Fetched 100 collections on page 99.
# Fetched 100 collections on page 100.
# Fetched 100 collections on page 101.
# Fetched 100 collections on page 102.
# Fetched 100 collections on page 103.
# Fetched 100 collections on page 104.
# Fetched 100 collections on page 105.
# Fetched 100 collections on page 106.
# Fetched 100 collections on page 107.
# Fetched 100 collections on page 108.
# Fetched 100 collections on page 109.
# Fetched 100 collections on page 110.
# Fetched 100 collections on page 111.
# Fetched 100 collections on page 112.
# Fetched 100 collections on page 113.
# Fetched 100 collections on page 114.
# Fetched 100 collections on page 115.
# Fetched 100 collections on page 116.
# Fetched 100 collections on page 117.
# Fetched 100 collections on page 118.
# Fetched 100 collections on page 119.
# Fetched 100 collections on page 120.
# Fetched 100 collections on page 121.
# Fetched 100 collections on page 122.
# Fetched 100 collections on page 123.
# Fetched 100 collections on page 124.
# Fetched 100 collections on page 125.
# Fetched 100 collections on page 126.
# Fetched 100 collections on page 127.
# Fetched 100 collections on page 128.
# Fetched 100 collections on page 129.
# Fetched 100 collections on page 130.
# Fetched 100 collections on page 131.
# Fetched 100 collections on page 132.
# Fetched 100 collections on page 133.
# Fetched 100 collections on page 134.
# Fetched 100 collections on page 135.
# Fetched 100 collections on page 136.
# Fetched 100 collections on page 137.
# Fetched 100 collections on page 138.
# Fetched 100 collections on page 139.
# Fetched 100 collections on page 140.
# Fetched 100 collections on page 141.
# Fetched 100 collections on page 142.
# Fetched 100 collections on page 143.
# Fetched 100 collections on page 144.
# Fetched 100 collections on page 145.
# Fetched 100 collections on page 146.
# Fetched 100 collections on page 147.
# Fetched 100 collections on page 148.
# Fetched 100 collections on page 149.
# Fetched 100 collections on page 150.
# Fetched 100 collections on page 151.
# Fetched 100 collections on page 152.
# Fetched 100 collections on page 153.
# Fetched 100 collections on page 154.
# Fetched 100 collections on page 155.
# Fetched 100 collections on page 156.
# Fetched 100 collections on page 157.
# Fetched 100 collections on page 158.
# Fetched 100 collections on page 159.
# Fetched 100 collections on page 160.
# Fetched 100 collections on page 161.
# Fetched 100 collections on page 162.
# Fetched 100 collections on page 163.
# Fetched 100 collections on page 164.
# Fetched 100 collections on page 165.
# Fetched 100 collections on page 166.
# Fetched 100 collections on page 167.
# Fetched 100 collections on page 168.
# Fetched 100 collections on page 169.
# Fetched 100 collections on page 170.
# Fetched 100 collections on page 171.
# Fetched 100 collections on page 172.
# Fetched 100 collections on page 173.
# Fetched 100 collections on page 174.
# Fetched 100 collections on page 175.
# Fetched 100 collections on page 176.
# Fetched 100 collections on page 177.
# Fetched 100 collections on page 178.
# Fetched 100 collections on page 179.
# Fetched 100 collections on page 180.
# Fetched 100 collections on page 181.
# Fetched 100 collections on page 182.
# Fetched 100 collections on page 183.
# Fetched 100 collections on page 184.
# Fetched 100 collections on page 185.
# Fetched 100 collections on page 186.
# Fetched 100 collections on page 187.
# Fetched 100 collections on page 188.
# Fetched 100 collections on page 189.
# Fetched 100 collections on page 190.
# Fetched 100 collections on page 191.
# Fetched 100 collections on page 192.
# Fetched 100 collections on page 193.
# Fetched 100 collections on page 194.
# Fetched 100 collections on page 195.
# Fetched 100 collections on page 196.
# Fetched 100 collections on page 197.
# Fetched 100 collections on page 198.
# Fetched 100 collections on page 199.
# Fetched 100 collections on page 200.
# Fetched 100 collections on page 201.
# Fetched 100 collections on page 202.
# Fetched 100 collections on page 203.
# Fetched 100 collections on page 204.
# Fetched 100 collections on page 205.
# Fetched 100 collections on page 206.
# Fetched 100 collections on page 207.
# Fetched 100 collections on page 208.
# Fetched 100 collections on page 209.
# Fetched 100 collections on page 210.
# Fetched 100 collections on page 211.
# Fetched 100 collections on page 212.
# Fetched 100 collections on page 213.
# Fetched 100 collections on page 214.
# Fetched 100 collections on page 215.
# Fetched 100 collections on page 216.
# Fetched 100 collections on page 217.
# Fetched 100 collections on page 218.
# Fetched 100 collections on page 219.
# Fetched 100 collections on page 220.
# Fetched 100 collections on page 221.
# Fetched 100 collections on page 222.
# Fetched 100 collections on page 223.
# Fetched 100 collections on page 224.
# Fetched 100 collections on page 225.
# Fetched 100 collections on page 226.
# Fetched 100 collections on page 227.
# Fetched 100 collections on page 228.
# Fetched 100 collections on page 229.
# Fetched 100 collections on page 230.
# Fetched 100 collections on page 231.
# Fetched 100 collections on page 232.
# Fetched 100 collections on page 233.
# Fetched 100 collections on page 234.
# Fetched 100 collections on page 235.
# Fetched 100 collections on page 236.
# Fetched 100 collections on page 237.
# Fetched 100 collections on page 238.
# Fetched 100 collections on page 239.
# Fetched 100 collections on page 240.
# Fetched 100 collections on page 241.
# Fetched 100 collections on page 242.
# Fetched 100 collections on page 243.
# Fetched 100 collections on page 244.
# Fetched 100 collections on page 245.
# Fetched 100 collections on page 246.
# Fetched 100 collections on page 247.
# Fetched 100 collections on page 248.
# Fetched 100 collections on page 249.
# Fetched 100 collections on page 250.
# Fetched 100 collections on page 251.
# Fetched 100 collections on page 252.
# Fetched 100 collections on page 253.
# Fetched 100 collections on page 254.
# Fetched 100 collections on page 255.
# Fetched 100 collections on page 256.
# Fetched 100 collections on page 257.
# Fetched 100 collections on page 258.
# Fetched 100 collections on page 259.
# Fetched 100 collections on page 260.
# Fetched 100 collections on page 261.
# Fetched 100 collections on page 262.
# Fetched 100 collections on page 263.
# Fetched 100 collections on page 264.
# Fetched 100 collections on page 265.
# Fetched 100 collections on page 266.
# Fetched 100 collections on page 267.
# Fetched 100 collections on page 268.
# Fetched 100 collections on page 269.
# Fetched 100 collections on page 270.
# Fetched 100 collections on page 271.
# Fetched 100 collections on page 272.
# Fetched 100 collections on page 273.
# Fetched 100 collections on page 274.
# Fetched 100 collections on page 275.
# Fetched 100 collections on page 276.
# Fetched 100 collections on page 277.
# Fetched 100 collections on page 278.
# Fetched 100 collections on page 279.
# Fetched 100 collections on page 280.
# Fetched 100 collections on page 281.
# Fetched 100 collections on page 282.
# Fetched 100 collections on page 283.
# Fetched 100 collections on page 284.
# Fetched 100 collections on page 285.
# Fetched 100 collections on page 286.
# Fetched 100 collections on page 287.
# Fetched 100 collections on page 288.
# Fetched 100 collections on page 289.
# Fetched 100 collections on page 290.
# Fetched 100 collections on page 291.
# Fetched 100 collections on page 292.
# Fetched 100 collections on page 293.
# Fetched 100 collections on page 294.
# Fetched 100 collections on page 295.
# Fetched 100 collections on page 296.
# Fetched 100 collections on page 297.
# Fetched 100 collections on page 298.
# Fetched 100 collections on page 299.
# Fetched 100 collections on page 300.
# Fetched 100 collections on page 301.
# Fetched 100 collections on page 302.
# Fetched 100 collections on page 303.
# Fetched 100 collections on page 304.
# Fetched 100 collections on page 305.
# Fetched 100 collections on page 306.
# Fetched 100 collections on page 307.
# Fetched 100 collections on page 308.
# Fetched 100 collections on page 309.
# Fetched 100 collections on page 310.
# Fetched 100 collections on page 311.
# Fetched 100 collections on page 312.
# Fetched 100 collections on page 313.
# Fetched 100 collections on page 314.
# Fetched 100 collections on page 315.
# Fetched 100 collections on page 316.
# Fetched 100 collections on page 317.
# Fetched 100 collections on page 318.
# Fetched 100 collections on page 319.
# Fetched 100 collections on page 320.
# Fetched 100 collections on page 321.
# Fetched 100 collections on page 322.
# Fetched 100 collections on page 323.
# Fetched 100 collections on page 324.
# Fetched 100 collections on page 325.
# Fetched 100 collections on page 326.
# Fetched 100 collections on page 327.
# Fetched 100 collections on page 328.
# Fetched 100 collections on page 329.
# Fetched 100 collections on page 330.
# Fetched 100 collections on page 331.
# Fetched 100 collections on page 332.
# Fetched 100 collections on page 333.
# Fetched 100 collections on page 334.
# Fetched 100 collections on page 335.
# Fetched 100 collections on page 336.
# Fetched 100 collections on page 337.
# Fetched 100 collections on page 338.
# Fetched 100 collections on page 339.
# Fetched 100 collections on page 340.
# Fetched 100 collections on page 341.
# Fetched 100 collections on page 342.
# Fetched 100 collections on page 343.
# Fetched 100 collections on page 344.
# Fetched 100 collections on page 345.
# Fetched 100 collections on page 346.
# Fetched 100 collections on page 347.
# Fetched 100 collections on page 348.
# Fetched 100 collections on page 349.
# Fetched 100 collections on page 350.
# Fetched 100 collections on page 351.
# Fetched 100 collections on page 352.
# Fetched 100 collections on page 353.
# Fetched 100 collections on page 354.
# Fetched 100 collections on page 355.
# Fetched 100 collections on page 356.
# Fetched 100 collections on page 357.
# Fetched 100 collections on page 358.
# Fetched 100 collections on page 359.
# Fetched 100 collections on page 360.
# Fetched 100 collections on page 361.
# Fetched 100 collections on page 362.
# Fetched 100 collections on page 363.
# Fetched 100 collections on page 364.
# Fetched 100 collections on page 365.
# Fetched 100 collections on page 366.
# Fetched 100 collections on page 367.
# Fetched 100 collections on page 368.
# Fetched 100 collections on page 369.
# Fetched 100 collections on page 370.
# Fetched 100 collections on page 371.
# Fetched 100 collections on page 372.
# Fetched 100 collections on page 373.
# Fetched 100 collections on page 374.
# Fetched 100 collections on page 375.
# Fetched 100 collections on page 376.
# Fetched 100 collections on page 377.
# Fetched 100 collections on page 378.
# Fetched 100 collections on page 379.
# Fetched 100 collections on page 380.
# Fetched 100 collections on page 381.
# Fetched 100 collections on page 382.
# Fetched 100 collections on page 383.
# Fetched 100 collections on page 384.
# Fetched 100 collections on page 385.
# Fetched 100 collections on page 386.
# Fetched 100 collections on page 387.
# Fetched 100 collections on page 388.
# Fetched 100 collections on page 389.
# Fetched 100 collections on page 390.
# Fetched 100 collections on page 391.
# Fetched 100 collections on page 392.
# Fetched 100 collections on page 393.
# Fetched 100 collections on page 394.
# Fetched 100 collections on page 395.
# Fetched 100 collections on page 396.
# Fetched 100 collections on page 397.
# Fetched 100 collections on page 398.
# Fetched 100 collections on page 399.
# Fetched 100 collections on page 400.
# Fetched 100 collections on page 401.
# Fetched 100 collections on page 402.
# Fetched 100 collections on page 403.
# Fetched 100 collections on page 404.
# Fetched 100 collections on page 405.
# Fetched 100 collections on page 406.
# Fetched 100 collections on page 407.
# Fetched 100 collections on page 408.
# Fetched 100 collections on page 409.
# Fetched 100 collections on page 410.
# Fetched 100 collections on page 411.
# Fetched 100 collections on page 412.
# Fetched 100 collections on page 413.
# Fetched 100 collections on page 414.
# Fetched 100 collections on page 415.
# Fetched 100 collections on page 416.
# Fetched 100 collections on page 417.
# Fetched 100 collections on page 418.
# Fetched 100 collections on page 419.
# Fetched 100 collections on page 420.
# Fetched 100 collections on page 421.
# Fetched 100 collections on page 422.
# Fetched 100 collections on page 423.
# Fetched 100 collections on page 424.
# Fetched 100 collections on page 425.
# Fetched 100 collections on page 426.
# Fetched 100 collections on page 427.
# Fetched 100 collections on page 428.
# Fetched 100 collections on page 429.
# Fetched 100 collections on page 430.
# Fetched 100 collections on page 431.
# Fetched 100 collections on page 432.
# Fetched 100 collections on page 433.
# Fetched 100 collections on page 434.
# Fetched 100 collections on page 435.
# Fetched 100 collections on page 436.
# Fetched 100 collections on page 437.
# Fetched 100 collections on page 438.
# Fetched 100 collections on page 439.
# Fetched 100 collections on page 440.
# Fetched 100 collections on page 441.
# Fetched 100 collections on page 442.
# Fetched 100 collections on page 443.
# Fetched 100 collections on page 444.
# Fetched 100 collections on page 445.
# Fetched 100 collections on page 446.
# Fetched 100 collections on page 447.
# Fetched 100 collections on page 448.
# Fetched 100 collections on page 449.
# Fetched 100 collections on page 450.
# Fetched 100 collections on page 451.
# Fetched 100 collections on page 452.
# Fetched 100 collections on page 453.
# Fetched 100 collections on page 454.
# Fetched 100 collections on page 455.
# Fetched 100 collections on page 456.
# Fetched 100 collections on page 457.
# Fetched 100 collections on page 458.
# Fetched 100 collections on page 459.
# Fetched 100 collections on page 460.
# Fetched 100 collections on page 461.
# Fetched 100 collections on page 462.
# Fetched 100 collections on page 463.
# Fetched 100 collections on page 464.
# Fetched 100 collections on page 465.
# Fetched 100 collections on page 466.
# Fetched 100 collections on page 467.
# Fetched 100 collections on page 468.
# Fetched 100 collections on page 469.
# Fetched 100 collections on page 470.
# Fetched 100 collections on page 471.
# Fetched 100 collections on page 472.
# Fetched 100 collections on page 473.
# Fetched 100 collections on page 474.
# Fetched 100 collections on page 475.
# Fetched 100 collections on page 476.
# Fetched 100 collections on page 477.
# Fetched 100 collections on page 478.
# Fetched 100 collections on page 479.
# Fetched 100 collections on page 480.
# Fetched 100 collections on page 481.
# Fetched 100 collections on page 482.
# Fetched 100 collections on page 483.
# Fetched 100 collections on page 484.
# Fetched 100 collections on page 485.
# Fetched 100 collections on page 486.
# Fetched 100 collections on page 487.
# Fetched 100 collections on page 488.
# Fetched 100 collections on page 489.
# Fetched 100 collections on page 490.
# Fetched 100 collections on page 491.
# Fetched 100 collections on page 492.
# Fetched 100 collections on page 493.
# Fetched 100 collections on page 494.
# Fetched 100 collections on page 495.
# Fetched 100 collections on page 496.
# Fetched 100 collections on page 497.
# Fetched 100 collections on page 498.
# Fetched 100 collections on page 499.
# Fetched 100 collections on page 500.
# Fetched 100 collections on page 501.
# Fetched 100 collections on page 502.
# Fetched 100 collections on page 503.
# Fetched 100 collections on page 504.
# Fetched 100 collections on page 505.
# Fetched 100 collections on page 506.
# Fetched 100 collections on page 507.
# Fetched 100 collections on page 508.
# Fetched 100 collections on page 509.
# Fetched 100 collections on page 510.
# Fetched 100 collections on page 511.
# Fetched 100 collections on page 512.
# Fetched 100 collections on page 513.
# Fetched 100 collections on page 514.
# Fetched 100 collections on page 515.
# Fetched 100 collections on page 516.
# Fetched 100 collections on page 517.
# Fetched 100 collections on page 518.
# Fetched 100 collections on page 519.
# Fetched 100 collections on page 520.
# Fetched 100 collections on page 521.
# Fetched 100 collections on page 522.
# Fetched 100 collections on page 523.
# Fetched 100 collections on page 524.
# Fetched 100 collections on page 525.
# Fetched 100 collections on page 526.
# Fetched 100 collections on page 527.
# Fetched 100 collections on page 528.
# Fetched 100 collections on page 529.
# Fetched 100 collections on page 530.
# Fetched 100 collections on page 531.
# Fetched 100 collections on page 532.
# Fetched 100 collections on page 533.
# Fetched 100 collections on page 534.
# Fetched 100 collections on page 535.
# Fetched 100 collections on page 536.
# Fetched 100 collections on page 537.
# Fetched 100 collections on page 538.
# Fetched 100 collections on page 539.
# Fetched 100 collections on page 540.
# Fetched 100 collections on page 541.
# Fetched 100 collections on page 542.
# Fetched 100 collections on page 543.
# Fetched 100 collections on page 544.
# Fetched 100 collections on page 545.
# Fetched 100 collections on page 546.
# Fetched 100 collections on page 547.
# Fetched 100 collections on page 548.
# Fetched 100 collections on page 549.
# Fetched 100 collections on page 550.
# Fetched 100 collections on page 551.
# Fetched 100 collections on page 552.
# Fetched 100 collections on page 553.
# Fetched 100 collections on page 554.
# Fetched 100 collections on page 555.
# Fetched 100 collections on page 556.
# Fetched 100 collections on page 557.
# Fetched 100 collections on page 558.
# Fetched 100 collections on page 559.
# Fetched 100 collections on page 560.
# Fetched 100 collections on page 561.
# Fetched 100 collections on page 562.
# Fetched 100 collections on page 563.
# Fetched 100 collections on page 564.
# Fetched 100 collections on page 565.
# Fetched 100 collections on page 566.
# Fetched 100 collections on page 567.
# Fetched 100 collections on page 568.
# Fetched 100 collections on page 569.
# Fetched 100 collections on page 570.
# Fetched 100 collections on page 571.
# Fetched 100 collections on page 572.
# Fetched 100 collections on page 573.
# Fetched 100 collections on page 574.
# Fetched 100 collections on page 575.
# Fetched 100 collections on page 576.
# Fetched 100 collections on page 577.
# Fetched 100 collections on page 578.
# Fetched 100 collections on page 579.
# Fetched 100 collections on page 580.
# Fetched 100 collections on page 581.
# Fetched 100 collections on page 582.
# Fetched 100 collections on page 583.
# Fetched 100 collections on page 584.
# Fetched 100 collections on page 585.
# Fetched 100 collections on page 586.
# Fetched 100 collections on page 587.
# Fetched 100 collections on page 588.
# Fetched 100 collections on page 589.
# Fetched 100 collections on page 590.
# Fetched 100 collections on page 591.
# Fetched 100 collections on page 592.
# Fetched 100 collections on page 593.
# Fetched 100 collections on page 594.
# Fetched 100 collections on page 595.
# Fetched 100 collections on page 596.
# Fetched 100 collections on page 597.
# Fetched 100 collections on page 598.
# Fetched 100 collections on page 599.
# Fetched 100 collections on page 600.
# Fetched 100 collections on page 601.
# Fetched 100 collections on page 602.
# Fetched 100 collections on page 603.
# Fetched 100 collections on page 604.
# Fetched 100 collections on page 605.
# Fetched 100 collections on page 606.
# Fetched 100 collections on page 607.
# Fetched 100 collections on page 608.
# Fetched 100 collections on page 609.
# Fetched 100 collections on page 610.
# Fetched 100 collections on page 611.
# Fetched 100 collections on page 612.
# Fetched 100 collections on page 613.
# Fetched 100 collections on page 614.
# Fetched 100 collections on page 615.
# Fetched 100 collections on page 616.
# Fetched 100 collections on page 617.
# Fetched 100 collections on page 618.
# Fetched 100 collections on page 619.
# Fetched 100 collections on page 620.
# Fetched 100 collections on page 621.
# Fetched 100 collections on page 622.
# Fetched 100 collections on page 623.
# Fetched 100 collections on page 624.
# Fetched 100 collections on page 625.
# Fetched 100 collections on page 626.
# Fetched 100 collections on page 627.
# Fetched 100 collections on page 628.
# Fetched 100 collections on page 629.
# Fetched 100 collections on page 630.
# Fetched 100 collections on page 631.
# Fetched 100 collections on page 632.
# Fetched 100 collections on page 633.
# Fetched 100 collections on page 634.
# Fetched 100 collections on page 635.
# Fetched 100 collections on page 636.
# Fetched 100 collections on page 637.
# Fetched 100 collections on page 638.
# Fetched 100 collections on page 639.
# Fetched 100 collections on page 640.
# Fetched 100 collections on page 641.
# Fetched 100 collections on page 642.
# Fetched 100 collections on page 643.
# Fetched 100 collections on page 644.
# Fetched 100 collections on page 645.
# Fetched 100 collections on page 646.
# Fetched 100 collections on page 647.
# Fetched 100 collections on page 648.
# Fetched 100 collections on page 649.
# Fetched 100 collections on page 650.
# Fetched 100 collections on page 651.
# Fetched 100 collections on page 652.
# Fetched 100 collections on page 653.
# Fetched 100 collections on page 654.
# Fetched 100 collections on page 655.
# Fetched 100 collections on page 656.
# Fetched 100 collections on page 657.
# Fetched 100 collections on page 658.
# Fetched 100 collections on page 659.
# Fetched 100 collections on page 660.
# Fetched 100 collections on page 661.
# Fetched 100 collections on page 662.
# Fetched 100 collections on page 663.
# Fetched 100 collections on page 664.
# Fetched 100 collections on page 665.
# Fetched 100 collections on page 666.
# Fetched 100 collections on page 667.
# Fetched 100 collections on page 668.
# Fetched 100 collections on page 669.
# Fetched 100 collections on page 670.
# Fetched 100 collections on page 671.
# Fetched 100 collections on page 672.
# Fetched 100 collections on page 673.
# Fetched 100 collections on page 674.
# Fetched 100 collections on page 675.
# Fetched 100 collections on page 676.
# Fetched 100 collections on page 677.
# Fetched 100 collections on page 678.
# Fetched 100 collections on page 679.
# Fetched 100 collections on page 680.
# Fetched 100 collections on page 681.
# Fetched 100 collections on page 682.
# Fetched 100 collections on page 683.
# Fetched 100 collections on page 684.
# Fetched 100 collections on page 685.
# Fetched 100 collections on page 686.
# Fetched 100 collections on page 687.
# Fetched 100 collections on page 688.
# Fetched 100 collections on page 689.
# Fetched 100 collections on page 690.
# Fetched 100 collections on page 691.
# Fetched 100 collections on page 692.
# Fetched 100 collections on page 693.
# Fetched 100 collections on page 694.
# Fetched 100 collections on page 695.
# Fetched 100 collections on page 696.
# Fetched 100 collections on page 697.
# Fetched 100 collections on page 698.
# Fetched 100 collections on page 699.
# Fetched 100 collections on page 700.
# Fetched 100 collections on page 701.
# Fetched 100 collections on page 702.
# Fetched 100 collections on page 703.
# Fetched 100 collections on page 704.
# Fetched 100 collections on page 705.
# Fetched 100 collections on page 706.
# Fetched 100 collections on page 707.
# Fetched 100 collections on page 708.
# Fetched 100 collections on page 709.
# Fetched 100 collections on page 710.
# Fetched 100 collections on page 711.
# Fetched 100 collections on page 712.
# Fetched 100 collections on page 713.
# Fetched 100 collections on page 714.
# Fetched 100 collections on page 715.
# Fetched 100 collections on page 716.
# Fetched 100 collections on page 717.
# Fetched 100 collections on page 718.
# Fetched 100 collections on page 719.
# Fetched 100 collections on page 720.
# Fetched 100 collections on page 721.
# Fetched 100 collections on page 722.
# Fetched 100 collections on page 723.
# Fetched 100 collections on page 724.
# Fetched 100 collections on page 725.
# Fetched 100 collections on page 726.
# Fetched 100 collections on page 727.
# Fetched 100 collections on page 728.
# Fetched 100 collections on page 729.
# Fetched 100 collections on page 730.
# Fetched 100 collections on page 731.
# Fetched 100 collections on page 732.
# Fetched 100 collections on page 733.
# Fetched 100 collections on page 734.
# Fetched 100 collections on page 735.
# Fetched 100 collections on page 736.
# Fetched 100 collections on page 737.
# Fetched 100 collections on page 738.
# Fetched 100 collections on page 739.
# Fetched 100 collections on page 740.
# Fetched 100 collections on page 741.
# Fetched 100 collections on page 742.
# Fetched 100 collections on page 743.
# Fetched 100 collections on page 744.
# Fetched 100 collections on page 745.
# Fetched 100 collections on page 746.
# Fetched 100 collections on page 747.
# Fetched 100 collections on page 748.
# Fetched 100 collections on page 749.
# Fetched 100 collections on page 750.
# Fetched 100 collections on page 751.
# Fetched 100 collections on page 752.
# Fetched 100 collections on page 753.
# Fetched 100 collections on page 754.
# Fetched 100 collections on page 755.
# Fetched 100 collections on page 756.
# Fetched 100 collections on page 757.
# Fetched 100 collections on page 758.
# Fetched 100 collections on page 759.
# Fetched 100 collections on page 760.
# Fetched 100 collections on page 761.
# Fetched 100 collections on page 762.
# Fetched 100 collections on page 763.
# Fetched 100 collections on page 764.
# Fetched 100 collections on page 765.
# Fetched 100 collections on page 766.
# Fetched 100 collections on page 767.
# Fetched 100 collections on page 768.
# Fetched 100 collections on page 769.
# Fetched 100 collections on page 770.
# Fetched 100 collections on page 771.
# Fetched 100 collections on page 772.
# Fetched 100 collections on page 773.
# Fetched 100 collections on page 774.
# Fetched 100 collections on page 775.
# Fetched 100 collections on page 776.
# Fetched 100 collections on page 777.
# Fetched 100 collections on page 778.
# Fetched 100 collections on page 779.
# Fetched 100 collections on page 780.
# Fetched 100 collections on page 781.
# Fetched 100 collections on page 782.
# Fetched 100 collections on page 783.
# Fetched 100 collections on page 784.
# Fetched 100 collections on page 785.
# Fetched 100 collections on page 786.
# Fetched 100 collections on page 787.
# Fetched 100 collections on page 788.
# Fetched 100 collections on page 789.
# Fetched 100 collections on page 790.
# Fetched 100 collections on page 791.
# Fetched 100 collections on page 792.
# Fetched 100 collections on page 793.
# Fetched 100 collections on page 794.
# Fetched 100 collections on page 795.
# Fetched 100 collections on page 796.
# Fetched 100 collections on page 797.
# Fetched 100 collections on page 798.
# Fetched 100 collections on page 799.
# Fetched 100 collections on page 800.
# Fetched 100 collections on page 801.
# Fetched 100 collections on page 802.
# Fetched 100 collections on page 803.
# Fetched 100 collections on page 804.
# Fetched 100 collections on page 805.
# Fetched 100 collections on page 806.
# Fetched 100 collections on page 807.
# Fetched 100 collections on page 808.
# Fetched 100 collections on page 809.
# Fetched 100 collections on page 810.
# Fetched 100 collections on page 811.
# Fetched 100 collections on page 812.
# Fetched 100 collections on page 813.
# Fetched 100 collections on page 814.
# Fetched 100 collections on page 815.
# Fetched 100 collections on page 816.
# Fetched 100 collections on page 817.
# Fetched 100 collections on page 818.
# Fetched 100 collections on page 819.
# Fetched 100 collections on page 820.
# Fetched 100 collections on page 821.
# Fetched 100 collections on page 822.
# Fetched 100 collections on page 823.
# Fetched 100 collections on page 824.
# Fetched 100 collections on page 825.
# Fetched 100 collections on page 826.
# Fetched 100 collections on page 827.
# Fetched 100 collections on page 828.
# Fetched 100 collections on page 829.
# Fetched 100 collections on page 830.
# Fetched 100 collections on page 831.
# Fetched 100 collections on page 832.
# Fetched 100 collections on page 833.
# Fetched 100 collections on page 834.
# Fetched 100 collections on page 835.
# Fetched 100 collections on page 836.
# Fetched 100 collections on page 837.
# Fetched 100 collections on page 838.
# Fetched 100 collections on page 839.
# Fetched 100 collections on page 840.
# Fetched 100 collections on page 841.
# Fetched 100 collections on page 842.
# Fetched 100 collections on page 843.
# Fetched 100 collections on page 844.
# Fetched 100 collections on page 845.
# Fetched 100 collections on page 846.
# Fetched 100 collections on page 847.
# Fetched 100 collections on page 848.
# Fetched 100 collections on page 849.
# Fetched 100 collections on page 850.
# Fetched 100 collections on page 851.
# Fetched 100 collections on page 852.
# Fetched 100 collections on page 853.
# Fetched 100 collections on page 854.
# Fetched 100 collections on page 855.
# Fetched 100 collections on page 856.
# Fetched 100 collections on page 857.
# Fetched 100 collections on page 858.
# Fetched 100 collections on page 859.
# Fetched 100 collections on page 860.
# Fetched 100 collections on page 861.
# Fetched 100 collections on page 862.
# Fetched 100 collections on page 863.
# Fetched 100 collections on page 864.
# Fetched 100 collections on page 865.
# Fetched 100 collections on page 866.
# Fetched 100 collections on page 867.
# Fetched 100 collections on page 868.
# Fetched 100 collections on page 869.
# Fetched 100 collections on page 870.
# Fetched 100 collections on page 871.
# Fetched 100 collections on page 872.
# Fetched 100 collections on page 873.
# Fetched 100 collections on page 874.
# Fetched 100 collections on page 875.
# Fetched 100 collections on page 876.
# Fetched 100 collections on page 877.
# Fetched 100 collections on page 878.
# Fetched 100 collections on page 879.
# Fetched 100 collections on page 880.
# Fetched 100 collections on page 881.
# Fetched 100 collections on page 882.
# Fetched 100 collections on page 883.
# Fetched 100 collections on page 884.
# Fetched 100 collections on page 885.
# Fetched 100 collections on page 886.
# Fetched 100 collections on page 887.
# Fetched 100 collections on page 888.
# Fetched 100 collections on page 889.
# Fetched 100 collections on page 890.
# Fetched 100 collections on page 891.
# Fetched 100 collections on page 892.
# Fetched 100 collections on page 893.
# Fetched 100 collections on page 894.
# Fetched 100 collections on page 895.
# Fetched 100 collections on page 896.
# Fetched 100 collections on page 897.
# Fetched 100 collections on page 898.
# Fetched 100 collections on page 899.
# Fetched 100 collections on page 900.
# Fetched 100 collections on page 901.
# Fetched 100 collections on page 902.
# Fetched 100 collections on page 903.
# Fetched 100 collections on page 904.
# Fetched 100 collections on page 905.
# Fetched 100 collections on page 906.
# Fetched 100 collections on page 907.
# Fetched 100 collections on page 908.
# Fetched 100 collections on page 909.
# Fetched 100 collections on page 910.
# Fetched 100 collections on page 911.
# Fetched 100 collections on page 912.
# Fetched 100 collections on page 913.
# Fetched 100 collections on page 914.
# Fetched 100 collections on page 915.
# Fetched 100 collections on page 916.
# Fetched 100 collections on page 917.
# Fetched 100 collections on page 918.
# Fetched 100 collections on page 919.
# Fetched 100 collections on page 920.
# Fetched 100 collections on page 921.
# Fetched 100 collections on page 922.
# Fetched 100 collections on page 923.
# Fetched 100 collections on page 924.
# Fetched 100 collections on page 925.
# Fetched 100 collections on page 926.
# Fetched 100 collections on page 927.
# Fetched 100 collections on page 928.
# Fetched 100 collections on page 929.
# Fetched 100 collections on page 930.
# Fetched 100 collections on page 931.
# Fetched 100 collections on page 932.
# Fetched 100 collections on page 933.
# Fetched 100 collections on page 934.
# Fetched 100 collections on page 935.
# Fetched 100 collections on page 936.
# Fetched 100 collections on page 937.
# Fetched 100 collections on page 938.
# Fetched 100 collections on page 939.
# Fetched 100 collections on page 940.
# Fetched 100 collections on page 941.
# Fetched 100 collections on page 942.
# Fetched 100 collections on page 943.
# Fetched 100 collections on page 944.
# Fetched 100 collections on page 945.
# Fetched 100 collections on page 946.
# Fetched 100 collections on page 947.
# Fetched 100 collections on page 948.
# Fetched 100 collections on page 949.
# Fetched 100 collections on page 950.
# Fetched 100 collections on page 951.
# Fetched 100 collections on page 952.
# Fetched 100 collections on page 953.
# Fetched 100 collections on page 954.
# Fetched 100 collections on page 955.
# Fetched 100 collections on page 956.
# Fetched 100 collections on page 957.
# Fetched 100 collections on page 958.
# Fetched 100 collections on page 959.
# Fetched 100 collections on page 960.
# Fetched 100 collections on page 961.
# Fetched 100 collections on page 962.
# Fetched 100 collections on page 963.
# Fetched 100 collections on page 964.
# Fetched 100 collections on page 965.
# Fetched 100 collections on page 966.
# Fetched 100 collections on page 967.
# Fetched 100 collections on page 968.
# Fetched 100 collections on page 969.
# Fetched 100 collections on page 970.
# Fetched 100 collections on page 971.
# Fetched 100 collections on page 972.
# Fetched 100 collections on page 973.
# Fetched 100 collections on page 974.
# Fetched 100 collections on page 975.
# Fetched 100 collections on page 976.
# Fetched 100 collections on page 977.
# Fetched 100 collections on page 978.
# Fetched 100 collections on page 979.
# Fetched 100 collections on page 980.
# Fetched 100 collections on page 981.
# Fetched 100 collections on page 982.
# Fetched 100 collections on page 983.
# Fetched 100 collections on page 984.
# Fetched 100 collections on page 985.
# Fetched 100 collections on page 986.
# Fetched 100 collections on page 987.
# Fetched 100 collections on page 988.
# Fetched 100 collections on page 989.
# Fetched 100 collections on page 990.
# Fetched 100 collections on page 991.
# Fetched 100 collections on page 992.
# Fetched 100 collections on page 993.
# Fetched 100 collections on page 994.
# Fetched 100 collections on page 995.
# Fetched 100 collections on page 996.
# Fetched 100 collections on page 997.
# Fetched 100 collections on page 998.
# Fetched 100 collections on page 999.
# Fetched 100 collections on page 1000.
# Fetched 100 collections on page 1001.
# Fetched 100 collections on page 1002.
# Fetched 100 collections on page 1003.
# Fetched 100 collections on page 1004.
# Fetched 100 collections on page 1005.
# Fetched 100 collections on page 1006.
# Fetched 100 collections on page 1007.
# Fetched 100 collections on page 1008.
# Fetched 100 collections on page 1009.
# Fetched 100 collections on page 1010.
# Fetched 100 collections on page 1011.
# Fetched 100 collections on page 1012.
# Fetched 100 collections on page 1013.
# Fetched 100 collections on page 1014.
# Fetched 100 collections on page 1015.
# Fetched 100 collections on page 1016.
# Fetched 100 collections on page 1017.
# Fetched 100 collections on page 1018.
# Fetched 100 collections on page 1019.
# Fetched 100 collections on page 1020.
# Fetched 100 collections on page 1021.
# Fetched 100 collections on page 1022.
# Fetched 100 collections on page 1023.
# Fetched 100 collections on page 1024.
# Fetched 100 collections on page 1025.
# Fetched 100 collections on page 1026.
# Fetched 100 collections on page 1027.
# Fetched 100 collections on page 1028.
# Fetched 100 collections on page 1029.
# Fetched 100 collections on page 1030.
# Fetched 100 collections on page 1031.
# Fetched 100 collections on page 1032.
# Fetched 100 collections on page 1033.
# Fetched 100 collections on page 1034.
# Fetched 100 collections on page 1035.
# Fetched 100 collections on page 1036.
# Fetched 100 collections on page 1037.
# Fetched 100 collections on page 1038.
# Fetched 100 collections on page 1039.
# Fetched 100 collections on page 1040.
# Fetched 100 collections on page 1041.
# Fetched 100 collections on page 1042.
# Fetched 100 collections on page 1043.
# Fetched 100 collections on page 1044.
# Fetched 100 collections on page 1045.
# Fetched 100 collections on page 1046.
# Fetched 100 collections on page 1047.
# Fetched 100 collections on page 1048.
# Fetched 100 collections on page 1049.
# Fetched 100 collections on page 1050.
# Fetched 100 collections on page 1051.
# Fetched 100 collections on page 1052.
# Fetched 100 collections on page 1053.
# Fetched 100 collections on page 1054.
# Fetched 100 collections on page 1055.
# Fetched 100 collections on page 1056.
# Fetched 100 collections on page 1057.
# Fetched 100 collections on page 1058.
# Fetched 100 collections on page 1059.
# Fetched 100 collections on page 1060.
# Fetched 100 collections on page 1061.
# Fetched 100 collections on page 1062.
# Fetched 100 collections on page 1063.
# Fetched 100 collections on page 1064.
# Fetched 100 collections on page 1065.
# Fetched 100 collections on page 1066.
# Fetched 100 collections on page 1067.
# Fetched 100 collections on page 1068.
# Fetched 100 collections on page 1069.
# Fetched 100 collections on page 1070.
# Fetched 100 collections on page 1071.
# Fetched 100 collections on page 1072.
# Fetched 100 collections on page 1073.
# Fetched 100 collections on page 1074.
# Fetched 100 collections on page 1075.
# Fetched 100 collections on page 1076.
# Fetched 100 collections on page 1077.
# Fetched 100 collections on page 1078.
# Fetched 100 collections on page 1079.
# Fetched 100 collections on page 1080.
# Fetched 100 collections on page 1081.
# Fetched 100 collections on page 1082.
# Fetched 100 collections on page 1083.
# Fetched 100 collections on page 1084.
# Fetched 100 collections on page 1085.
# Fetched 100 collections on page 1086.
# Fetched 100 collections on page 1087.
# Fetched 100 collections on page 1088.
# Fetched 100 collections on page 1089.
# Fetched 100 collections on page 1090.
# Fetched 100 collections on page 1091.
# Fetched 100 collections on page 1092.
# Fetched 100 collections on page 1093.
# Fetched 100 collections on page 1094.
# Fetched 100 collections on page 1095.
# Fetched 100 collections on page 1096.
# Fetched 100 collections on page 1097.
# Fetched 100 collections on page 1098.
# Fetched 100 collections on page 1099.
# Fetched 100 collections on page 1100.
# Fetched 100 collections on page 1101.
# Fetched 100 collections on page 1102.
# Fetched 100 collections on page 1103.
# Fetched 100 collections on page 1104.
# Fetched 100 collections on page 1105.
# Fetched 100 collections on page 1106.
# Fetched 100 collections on page 1107.
# Fetched 100 collections on page 1108.
# Fetched 100 collections on page 1109.
# Fetched 100 collections on page 1110.
# Fetched 100 collections on page 1111.
# Fetched 100 collections on page 1112.
# Fetched 100 collections on page 1113.
# Fetched 100 collections on page 1114.
# Fetched 100 collections on page 1115.
# Fetched 100 collections on page 1116.
# Fetched 100 collections on page 1117.
# Fetched 100 collections on page 1118.
# Fetched 100 collections on page 1119.
# Fetched 100 collections on page 1120.
# Fetched 100 collections on page 1121.
# Fetched 100 collections on page 1122.
# Fetched 100 collections on page 1123.
# Fetched 100 collections on page 1124.
# Fetched 100 collections on page 1125.
# Fetched 100 collections on page 1126.
# Fetched 100 collections on page 1127.
# Fetched 100 collections on page 1128.
# Fetched 100 collections on page 1129.
# Fetched 100 collections on page 1130.
# Fetched 100 collections on page 1131.
# Fetched 100 collections on page 1132.
# Fetched 100 collections on page 1133.
# Fetched 100 collections on page 1134.
# Fetched 100 collections on page 1135.
# Fetched 100 collections on page 1136.
# Fetched 100 collections on page 1137.
# Fetched 100 collections on page 1138.
# Fetched 100 collections on page 1139.
# Fetched 100 collections on page 1140.
# Fetched 100 collections on page 1141.
# Fetched 100 collections on page 1142.
# Fetched 100 collections on page 1143.
# Fetched 100 collections on page 1144.
# Fetched 100 collections on page 1145.
# Fetched 100 collections on page 1146.
# Fetched 100 collections on page 1147.
# Fetched 100 collections on page 1148.
# Fetched 100 collections on page 1149.
# Fetched 100 collections on page 1150.
# Fetched 100 collections on page 1151.
# Fetched 100 collections on page 1152.
# Fetched 100 collections on page 1153.
# Fetched 100 collections on page 1154.
# Fetched 100 collections on page 1155.
# Fetched 100 collections on page 1156.
# Fetched 100 collections on page 1157.
# Fetched 100 collections on page 1158.
# Fetched 100 collections on page 1159.
# Fetched 100 collections on page 1160.
# Fetched 100 collections on page 1161.
# Fetched 100 collections on page 1162.
# Fetched 100 collections on page 1163.
# Fetched 100 collections on page 1164.
# Fetched 100 collections on page 1165.
# Fetched 100 collections on page 1166.
# Fetched 100 collections on page 1167.
# Fetched 100 collections on page 1168.
# Fetched 100 collections on page 1169.
# Fetched 100 collections on page 1170.
# Fetched 100 collections on page 1171.
# Fetched 100 collections on page 1172.
# Fetched 100 collections on page 1173.
# Fetched 100 collections on page 1174.
# Fetched 100 collections on page 1175.
# Fetched 100 collections on page 1176.
# Fetched 100 collections on page 1177.
# Fetched 100 collections on page 1178.
# Fetched 100 collections on page 1179.
# Fetched 100 collections on page 1180.
# Fetched 100 collections on page 1181.
# Fetched 100 collections on page 1182.
# Fetched 100 collections on page 1183.
# Fetched 100 collections on page 1184.
# Fetched 100 collections on page 1185.
# Fetched 100 collections on page 1186.
# Fetched 100 collections on page 1187.
# Fetched 100 collections on page 1188.
# Fetched 100 collections on page 1189.
# Fetched 100 collections on page 1190.
# Fetched 100 collections on page 1191.
# Fetched 100 collections on page 1192.
# Fetched 100 collections on page 1193.
# Fetched 100 collections on page 1194.
# Fetched 100 collections on page 1195.
# Fetched 100 collections on page 1196.
# Fetched 100 collections on page 1197.
# Fetched 100 collections on page 1198.
# Fetched 100 collections on page 1199.
# Fetched 100 collections on page 1200.
# Fetched 100 collections on page 1201.
# Fetched 100 collections on page 1202.
# Fetched 100 collections on page 1203.
# Fetched 100 collections on page 1204.
# Fetched 100 collections on page 1205.
# Fetched 100 collections on page 1206.
# Fetched 100 collections on page 1207.
# Fetched 100 collections on page 1208.
# Fetched 100 collections on page 1209.
# Fetched 100 collections on page 1210.
# Fetched 100 collections on page 1211.
# Fetched 100 collections on page 1212.
# Fetched 100 collections on page 1213.
# Fetched 100 collections on page 1214.
# Fetched 100 collections on page 1215.
# Fetched 100 collections on page 1216.
# Fetched 100 collections on page 1217.
# Fetched 100 collections on page 1218.
# Fetched 100 collections on page 1219.
# Fetched 100 collections on page 1220.
# Fetched 100 collections on page 1221.
# Fetched 100 collections on page 1222.
# Fetched 100 collections on page 1223.
# Fetched 100 collections on page 1224.
# Fetched 100 collections on page 1225.
# Fetched 100 collections on page 1226.
# Fetched 100 collections on page 1227.
# Fetched 100 collections on page 1228.
# Fetched 100 collections on page 1229.
# Fetched 100 collections on page 1230.
# Fetched 100 collections on page 1231.
# Fetched 100 collections on page 1232.
# Fetched 100 collections on page 1233.
# Fetched 100 collections on page 1234.
# Fetched 100 collections on page 1235.
# Fetched 100 collections on page 1236.
# Fetched 100 collections on page 1237.
# Fetched 100 collections on page 1238.
# Fetched 100 collections on page 1239.
# Fetched 100 collections on page 1240.
# Fetched 100 collections on page 1241.
# Fetched 100 collections on page 1242.
# Fetched 100 collections on page 1243.
# Fetched 100 collections on page 1244.
# Fetched 100 collections on page 1245.
# Fetched 100 collections on page 1246.
# Fetched 100 collections on page 1247.
# Fetched 100 collections on page 1248.
# Fetched 100 collections on page 1249.
# Fetched 100 collections on page 1250.
# Fetched 100 collections on page 1251.
# Fetched 100 collections on page 1252.
# Fetched 100 collections on page 1253.
# Fetched 100 collections on page 1254.
# Fetched 100 collections on page 1255.
# Fetched 100 collections on page 1256.
# Fetched 100 collections on page 1257.
# Fetched 100 collections on page 1258.
# Fetched 100 collections on page 1259.
# Fetched 100 collections on page 1260.
# Fetched 100 collections on page 1261.
# Fetched 100 collections on page 1262.
# Fetched 100 collections on page 1263.
# Fetched 100 collections on page 1264.
# Fetched 100 collections on page 1265.
# Fetched 100 collections on page 1266.
# Fetched 100 collections on page 1267.
# Fetched 100 collections on page 1268.
# Fetched 100 collections on page 1269.
# Fetched 100 collections on page 1270.
# Fetched 100 collections on page 1271.
# Fetched 100 collections on page 1272.
# Fetched 100 collections on page 1273.
# Fetched 100 collections on page 1274.
# Fetched 100 collections on page 1275.
# Fetched 100 collections on page 1276.
# Fetched 100 collections on page 1277.
# Fetched 100 collections on page 1278.
# Fetched 100 collections on page 1279.
# Fetched 100 collections on page 1280.
# Fetched 100 collections on page 1281.
# Fetched 100 collections on page 1282.
# Fetched 100 collections on page 1283.
# Fetched 100 collections on page 1284.
# Fetched 100 collections on page 1285.
# Fetched 100 collections on page 1286.
# Fetched 100 collections on page 1287.
# Fetched 100 collections on page 1288.
# Fetched 100 collections on page 1289.
# Fetched 100 collections on page 1290.
# Fetched 100 collections on page 1291.
# Fetched 100 collections on page 1292.
# ...
# Fetched 100 collections on page 41608.
# Fetched 100 collections on page 41609.
# Fetched 100 collections on page 41610.
# Fetched 100 collections on page 41611.
# Fetched 100 collections on page 41612.
# Fetched 100 collections on page 41613.
# Fetched 100 collections on page 41614.
# Fetched 100 collections on page 41615.
# Fetched 100 collections on page 41616.
# Fetched 100 collections on page 41617.
# Fetched 100 collections on page 41618.
# Fetched 100 collections on page 41619.
# Fetched 100 collections on page 41620.
# Fetched 100 collections on page 41621.
# Fetched 100 collections on page 41622.
# Fetched 100 collections on page 41623.
# Fetched 100 collections on page 41624.
# Fetched 100 collections on page 41625.
# Fetched 100 collections on page 41626.
# Fetched 100 collections on page 41627.
# Fetched 100 collections on page 41628.
# Fetched 100 collections on page 41629.
# Fetched 100 collections on page 41630.
# Fetched 100 collections on page 41631.
# Fetched 100 collections on page 41632.
# Fetched 100 collections on page 41633.
# Fetched 100 collections on page 41634.
# Fetched 100 collections on page 41635.
# Fetched 100 collections on page 41636.
# Fetched 100 collections on page 41637.
# Fetched 100 collections on page 41638.
# Fetched 100 collections on page 41639.
# Fetched 100 collections on page 41640.
# Fetched 100 collections on page 41641.
# Fetched 100 collections on page 41642.
# Fetched 100 collections on page 41643.
# Fetched 100 collections on page 41644.
# Fetched 100 collections on page 41645.
# Fetched 100 collections on page 41646.
# Fetched 100 collections on page 41647.
# Fetched 100 collections on page 41648.
# Fetched 100 collections on page 41649.
# Fetched 100 collections on page 41650.
# Fetched 100 collections on page 41651.
# Fetched 100 collections on page 41652.
# Fetched 100 collections on page 41653.
# Fetched 100 collections on page 41654.
# Fetched 100 collections on page 41655.
# Fetched 100 collections on page 41656.
# Fetched 100 collections on page 41657.
# Fetched 100 collections on page 41658.
# Fetched 100 collections on page 41659.
# Fetched 100 collections on page 41660.
# Fetched 100 collections on page 41661.
# Fetched 100 collections on page 41662.
# Fetched 100 collections on page 41663.
# Fetched 100 collections on page 41664.
# Fetched 100 collections on page 41665.
# Fetched 100 collections on page 41666.
# Fetched 100 collections on page 41667.
# Fetched 100 collections on page 41668.
# Fetched 100 collections on page 41669.
# Fetched 100 collections on page 41670.
# Fetched 100 collections on page 41671.
# Fetched 100 collections on page 41672.
# Fetched 100 collections on page 41673.
# Fetched 100 collections on page 41674.
# Fetched 100 collections on page 41675.
# Fetched 100 collections on page 41676.
# Fetched 100 collections on page 41677.
# Fetched 100 collections on page 41678.
# Fetched 100 collections on page 41679.
# Fetched 100 collections on page 41680.
# Fetched 100 collections on page 41681.
# Fetched 100 collections on page 41682.
# Fetched 100 collections on page 41683.
# Fetched 100 collections on page 41684.
# Fetched 100 collections on page 41685.
# Fetched 100 collections on page 41686.
# Fetched 100 collections on page 41687.
# Fetched 100 collections on page 41688.
# Fetched 100 collections on page 41689.
# Fetched 100 collections on page 41690.
# Fetched 100 collections on page 41691.
# Fetched 100 collections on page 41692.
# Fetched 100 collections on page 41693.
# Fetched 100 collections on page 41694.
# Fetched 100 collections on page 41695.
# Fetched 100 collections on page 41696.
# Fetched 100 collections on page 41697.
# Fetched 100 collections on page 41698.
# Fetched 100 collections on page 41699.
# Fetched 100 collections on page 41700.
# Fetched 100 collections on page 41701.
# Fetched 100 collections on page 41702.
# Fetched 100 collections on page 41703.
# Fetched 100 collections on page 41704.
# Fetched 100 collections on page 41705.
# Fetched 100 collections on page 41706.
# Fetched 100 collections on page 41707.
# Fetched 100 collections on page 41708.
# Fetched 100 collections on page 41709.
# Fetched 100 collections on page 41710.
# Fetched 100 collections on page 41711.
# Fetched 100 collections on page 41712.
# Fetched 100 collections on page 41713.
# Fetched 100 collections on page 41714.
# Fetched 100 collections on page 41715.
# Fetched 100 collections on page 41716.
# Fetched 100 collections on page 41717.
# Fetched 100 collections on page 41718.
# Fetched 100 collections on page 41719.
# Fetched 100 collections on page 41720.
# Fetched 100 collections on page 41721.
# Fetched 100 collections on page 41722.
# Fetched 100 collections on page 41723.
# Fetched 100 collections on page 41724.
# Fetched 100 collections on page 41725.
# Fetched 100 collections on page 41726.
# Fetched 100 collections on page 41727.
# Fetched 100 collections on page 41728.
# Fetched 100 collections on page 41729.
# Fetched 100 collections on page 41730.
# Fetched 100 collections on page 41731.
# Fetched 100 collections on page 41732.
# Fetched 100 collections on page 41733.
# Fetched 100 collections on page 41734.
# Fetched 100 collections on page 41735.
# Fetched 100 collections on page 41736.
# Fetched 100 collections on page 41737.
# Fetched 100 collections on page 41738.
# Fetched 100 collections on page 41739.
# Fetched 100 collections on page 41740.
# Fetched 100 collections on page 41741.
# Fetched 100 collections on page 41742.
# Fetched 100 collections on page 41743.
# Fetched 100 collections on page 41744.
# Fetched 100 collections on page 41745.
# Fetched 100 collections on page 41746.
# Fetched 100 collections on page 41747.
# Fetched 100 collections on page 41748.
# Fetched 100 collections on page 41749.
# Fetched 100 collections on page 41750.
# Fetched 100 collections on page 41751.
# Fetched 100 collections on page 41752.
# Fetched 100 collections on page 41753.
# Fetched 100 collections on page 41754.
# Fetched 100 collections on page 41755.
# Fetched 100 collections on page 41756.
# Fetched 100 collections on page 41757.
# Fetched 100 collections on page 41758.
# Fetched 100 collections on page 41759.
# Fetched 100 collections on page 41760.
# Fetched 100 collections on page 41761.
# Fetched 100 collections on page 41762.
# Fetched 100 collections on page 41763.
# Fetched 100 collections on page 41764.
# Fetched 100 collections on page 41765.
# Fetched 100 collections on page 41766.
# Fetched 100 collections on page 41767.
# Fetched 100 collections on page 41768.
# Fetched 100 collections on page 41769.
# Fetched 100 collections on page 41770.
# Fetched 100 collections on page 41771.
# Fetched 100 collections on page 41772.
# Fetched 100 collections on page 41773.
# Fetched 100 collections on page 41774.
# Fetched 100 collections on page 41775.
# Fetched 100 collections on page 41776.
# Fetched 100 collections on page 41777.
# Fetched 100 collections on page 41778.
# Fetched 100 collections on page 41779.
# Fetched 100 collections on page 41780.
# Fetched 100 collections on page 41781.
# Fetched 100 collections on page 41782.
# Fetched 100 collections on page 41783.
# Fetched 100 collections on page 41784.
# Fetched 100 collections on page 41785.
# Fetched 100 collections on page 41786.
# Fetched 100 collections on page 41787.
# Fetched 100 collections on page 41788.
# Fetched 100 collections on page 41789.
# Fetched 100 collections on page 41790.
# Fetched 100 collections on page 41791.
# Fetched 100 collections on page 41792.
# Fetched 100 collections on page 41793.
# Fetched 100 collections on page 41794.
# Fetched 100 collections on page 41795.
# Fetched 100 collections on page 41796.
# Fetched 100 collections on page 41797.
# Fetched 100 collections on page 41798.
# Fetched 100 collections on page 41799.
# Fetched 100 collections on page 41800.
# Fetched 100 collections on page 41801.
# Fetched 100 collections on page 41802.
# Fetched 100 collections on page 41803.
# Fetched 100 collections on page 41804.
# Fetched 100 collections on page 41805.
# Fetched 100 collections on page 41806.
# Fetched 100 collections on page 41807.
# Fetched 100 collections on page 41808.
# Fetched 100 collections on page 41809.
# Fetched 100 collections on page 41810.
# Fetched 100 collections on page 41811.
# Fetched 100 collections on page 41812.
# Fetched 100 collections on page 41813.
# Fetched 100 collections on page 41814.
# Fetched 100 collections on page 41815.
# Fetched 100 collections on page 41816.
# Fetched 100 collections on page 41817.
# Fetched 100 collections on page 41818.
# Fetched 100 collections on page 41819.
# Fetched 100 collections on page 41820.
# Fetched 100 collections on page 41821.
# Fetched 100 collections on page 41822.
# Fetched 100 collections on page 41823.
# Fetched 100 collections on page 41824.
# Fetched 100 collections on page 41825.
# Fetched 100 collections on page 41826.
# Fetched 100 collections on page 41827.
# Fetched 100 collections on page 41828.
# Fetched 100 collections on page 41829.
# Fetched 100 collections on page 41830.
# Fetched 100 collections on page 41831.
# Fetched 100 collections on page 41832.
# Fetched 100 collections on page 41833.
# Fetched 100 collections on page 41834.
# Fetched 100 collections on page 41835.
# Fetched 100 collections on page 41836.
# Fetched 100 collections on page 41837.
# Fetched 100 collections on page 41838.
# Fetched 100 collections on page 41839.
# Fetched 100 collections on page 41840.
# Fetched 100 collections on page 41841.
# Fetched 100 collections on page 41842.
# Fetched 100 collections on page 41843.
# Fetched 100 collections on page 41844.
# Fetched 100 collections on page 41845.
# Fetched 100 collections on page 41846.
# Fetched 100 collections on page 41847.
# Fetched 100 collections on page 41848.
# Fetched 100 collections on page 41849.
# Fetched 100 collections on page 41850.
# Fetched 100 collections on page 41851.
# Fetched 100 collections on page 41852.
# Fetched 100 collections on page 41853.
# Fetched 100 collections on page 41854.
# Fetched 100 collections on page 41855.
# Fetched 100 collections on page 41856.
# Fetched 100 collections on page 41857.
# Fetched 100 collections on page 41858.
# Fetched 100 collections on page 41859.
# Fetched 100 collections on page 41860.
# Fetched 100 collections on page 41861.
# Fetched 100 collections on page 41862.
# Fetched 100 collections on page 41863.
# Fetched 100 collections on page 41864.
# Fetched 100 collections on page 41865.
# Fetched 100 collections on page 41866.
# Fetched 100 collections on page 41867.
# Fetched 100 collections on page 41868.
# Fetched 100 collections on page 41869.
# Fetched 100 collections on page 41870.
# Fetched 100 collections on page 41871.
# Fetched 100 collections on page 41872.
# Fetched 100 collections on page 41873.
# Fetched 100 collections on page 41874.
# Fetched 100 collections on page 41875.
# Fetched 100 collections on page 41876.
# Fetched 100 collections on page 41877.
# Fetched 100 collections on page 41878.
# Fetched 100 collections on page 41879.
# Fetched 100 collections on page 41880.
# Fetched 100 collections on page 41881.
# Fetched 100 collections on page 41882.
# Fetched 100 collections on page 41883.
# Fetched 100 collections on page 41884.
# Fetched 100 collections on page 41885.
# Fetched 100 collections on page 41886.
# Fetched 100 collections on page 41887.
# Fetched 100 collections on page 41888.
# Fetched 100 collections on page 41889.
# Fetched 100 collections on page 41890.
# Fetched 100 collections on page 41891.
# Fetched 100 collections on page 41892.
# Fetched 100 collections on page 41893.
# Fetched 100 collections on page 41894.
# Fetched 100 collections on page 41895.
# Fetched 100 collections on page 41896.
# Fetched 100 collections on page 41897.
# Fetched 100 collections on page 41898.
# Fetched 100 collections on page 41899.
# Fetched 100 collections on page 41900.
# Fetched 100 collections on page 41901.
# Fetched 100 collections on page 41902.
# Fetched 100 collections on page 41903.
# Fetched 100 collections on page 41904.
# Fetched 100 collections on page 41905.
# Fetched 100 collections on page 41906.
# Fetched 100 collections on page 41907.
# Fetched 100 collections on page 41908.
# Fetched 100 collections on page 41909.
# Fetched 100 collections on page 41910.
# Fetched 100 collections on page 41911.
# Fetched 100 collections on page 41912.
# Fetched 100 collections on page 41913.
# Fetched 100 collections on page 41914.
# Fetched 100 collections on page 41915.
# Fetched 100 collections on page 41916.
# Fetched 100 collections on page 41917.
# Fetched 100 collections on page 41918.
# Fetched 100 collections on page 41919.
# Fetched 100 collections on page 41920.
# Fetched 100 collections on page 41921.
# Fetched 100 collections on page 41922.
# Fetched 100 collections on page 41923.
# Fetched 100 collections on page 41924.
# Fetched 100 collections on page 41925.
# Fetched 100 collections on page 41926.
# Fetched 100 collections on page 41927.
# Fetched 100 collections on page 41928.
# Fetched 100 collections on page 41929.
# Fetched 100 collections on page 41930.
# Fetched 100 collections on page 41931.
# Fetched 100 collections on page 41932.
# Fetched 100 collections on page 41933.
# Fetched 100 collections on page 41934.
# Fetched 100 collections on page 41935.
# Fetched 100 collections on page 41936.
# Fetched 100 collections on page 41937.
# Fetched 100 collections on page 41938.
# Fetched 100 collections on page 41939.
# Fetched 100 collections on page 41940.
# Fetched 100 collections on page 41941.
# Fetched 100 collections on page 41942.
# Fetched 100 collections on page 41943.
# Fetched 100 collections on page 41944.
# Fetched 100 collections on page 41945.
# Fetched 100 collections on page 41946.
# Fetched 100 collections on page 41947.
# Fetched 100 collections on page 41948.
# Fetched 100 collections on page 41949.
# Fetched 100 collections on page 41950.
# Fetched 100 collections on page 41951.
# Fetched 100 collections on page 41952.
# Fetched 100 collections on page 41953.
# Fetched 100 collections on page 41954.
# Fetched 100 collections on page 41955.
# Fetched 100 collections on page 41956.
# Fetched 100 collections on page 41957.
# Fetched 100 collections on page 41958.
# Fetched 100 collections on page 41959.
# Fetched 100 collections on page 41960.
# Fetched 100 collections on page 41961.
# Fetched 100 collections on page 41962.
# Fetched 100 collections on page 41963.
# Fetched 100 collections on page 41964.
# Fetched 100 collections on page 41965.
# Fetched 100 collections on page 41966.
# Fetched 100 collections on page 41967.
# Fetched 100 collections on page 41968.
# Fetched 100 collections on page 41969.
# Fetched 100 collections on page 41970.
# Fetched 100 collections on page 41971.
# Fetched 100 collections on page 41972.
# Fetched 100 collections on page 41973.
# Fetched 100 collections on page 41974.
# Fetched 100 collections on page 41975.
# Fetched 100 collections on page 41976.
# Fetched 100 collections on page 41977.
# Fetched 100 collections on page 41978.
# Fetched 100 collections on page 41979.
# Fetched 100 collections on page 41980.
# Fetched 100 collections on page 41981.
# Fetched 100 collections on page 41982.
# Fetched 100 collections on page 41983.
# Fetched 100 collections on page 41984.
# Fetched 100 collections on page 41985.
# Fetched 100 collections on page 41986.
# Fetched 100 collections on page 41987.
# Fetched 100 collections on page 41988.
# Fetched 100 collections on page 41989.
# Fetched 100 collections on page 41990.
# Fetched 100 collections on page 41991.
# Fetched 100 collections on page 41992.
# Fetched 100 collections on page 41993.
# Fetched 100 collections on page 41994.
# Fetched 100 collections on page 41995.
# Fetched 100 collections on page 41996.
# Fetched 100 collections on page 41997.
# Fetched 100 collections on page 41998.
# Fetched 100 collections on page 41999.
# Fetched 100 collections on page 42000.
# Fetched 100 collections on page 42001.
# Fetched 100 collections on page 42002.
# Fetched 100 collections on page 42003.
# Fetched 100 collections on page 42004.
# Fetched 100 collections on page 42005.
# Fetched 100 collections on page 42006.
# Fetched 100 collections on page 42007.
# Fetched 100 collections on page 42008.
# Fetched 100 collections on page 42009.
# Fetched 100 collections on page 42010.
# Fetched 100 collections on page 42011.
# Fetched 100 collections on page 42012.
# Fetched 100 collections on page 42013.
# Fetched 100 collections on page 42014.
# Fetched 49 collections on page 42015.
# No collections returned. Stopping.
# Finished. Pages fetched: 42015

# %% [markdown]
# # Magic Eden

# %%
def create_table_if_not_exists(conn):
    create_sql = """
    CREATE TABLE IF NOT EXISTS magiceden_collections (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        symbol TEXT,
        name TEXT,
        description TEXT,
        image TEXT,
        twitter TEXT,
        discord TEXT,
        website TEXT,
        categories TEXT,
        updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
    """
    conn.execute(create_sql)
    conn.commit()

def insert_collections(conn, collections_data):
    insert_sql = """
    INSERT INTO magiceden_collections (
        symbol,
        name,
        description,
        image,
        twitter,
        discord,
        website,
        categories
    ) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
    """

    records = []
    for item in collections_data:
        symbol = item.get("symbol", "")
        name = item.get("name", "")
        description = item.get("description", "")
        image = item.get("image", "")
        twitter = item.get("twitter", "")
        discord = item.get("discord", "")
        website = item.get("website", "")
        # store categories as JSON string (or comma-separated, up to you)
        categories_str = json.dumps(item.get("categories", []))

        row = (symbol, name, description, image, twitter, discord, website, categories_str)
        records.append(row)

    conn.executemany(insert_sql, records)
    conn.commit()

def fetch_all_magiceden_collections():
    conn = sqlite3.connect("data/collections_magiceden.db")
    create_table_if_not_exists(conn)

    base_url = "https://api-mainnet.magiceden.dev/v2/collections"
    limit = 100
    offset = 0
    page_count = 0

    while True:
        params = {
            "offset": offset,
            "limit": limit
        }
        headers = {
            "accept": "application/json",
            "paging": "true"
        }

        try:
            response = requests.get(base_url, headers=headers, params=params)
        except requests.exceptions.RequestException as e:
            print(f"Request exception: {e}. Stopping.")
            break

        if response.status_code == 200:
            data = response.json()
            if not data:
                print("No more collections returned. Stopping.")
                break

            # Insert into DB
            insert_collections(conn, data)

            page_count += 1
            print(f"Fetched {len(data)} collections on page {page_count} (offset={offset}).")

            # If we got fewer than limit, presumably no more data
            if len(data) < limit:
                print("Received fewer than 'limit' items. Stopping pagination.")
                break

            offset += limit

        elif response.status_code == 400:
            # We got the "offset and limit must be multiples of 20" or
            # "offset must be a multiple of the limit" message
            print(f"400 Bad Request: {response.text}")
            print("Likely reached an internal offset limit or no more data is available.")
            break
        else:
            print(f"Non-200 status code {response.status_code}. Response: {response.text}")
            break

        # optional small delay
        time.sleep(0.1)

    conn.close()
    print(f"Finished scraping. Total pages: {page_count}")

# %%
if __name__ == "__main__":
    fetch_all_magiceden_collections()
# Out:
# Fetched 100 collections on page 1 (offset=0).
# Fetched 100 collections on page 2 (offset=100).
# Fetched 100 collections on page 3 (offset=200).
# Fetched 100 collections on page 4 (offset=300).
# Fetched 100 collections on page 5 (offset=400).
# Fetched 100 collections on page 6 (offset=500).
# Fetched 100 collections on page 7 (offset=600).
# Fetched 100 collections on page 8 (offset=700).
# Fetched 100 collections on page 9 (offset=800).
# Fetched 100 collections on page 10 (offset=900).
# Fetched 100 collections on page 11 (offset=1000).
# Fetched 100 collections on page 12 (offset=1100).
# Fetched 100 collections on page 13 (offset=1200).
# Fetched 100 collections on page 14 (offset=1300).
# Fetched 100 collections on page 15 (offset=1400).
# Fetched 100 collections on page 16 (offset=1500).
# Fetched 100 collections on page 17 (offset=1600).
# Fetched 100 collections on page 18 (offset=1700).
# Fetched 100 collections on page 19 (offset=1800).
# Fetched 100 collections on page 20 (offset=1900).
# Fetched 100 collections on page 21 (offset=2000).
# Fetched 100 collections on page 22 (offset=2100).
# Fetched 100 collections on page 23 (offset=2200).
# Fetched 100 collections on page 24 (offset=2300).
# Fetched 100 collections on page 25 (offset=2400).
# Fetched 100 collections on page 26 (offset=2500).
# Fetched 100 collections on page 27 (offset=2600).
# Fetched 100 collections on page 28 (offset=2700).
# Fetched 100 collections on page 29 (offset=2800).
# Fetched 100 collections on page 30 (offset=2900).
# Fetched 100 collections on page 31 (offset=3000).
# Fetched 100 collections on page 32 (offset=3100).
# Fetched 100 collections on page 33 (offset=3200).
# Fetched 100 collections on page 34 (offset=3300).
# Fetched 100 collections on page 35 (offset=3400).
# Fetched 100 collections on page 36 (offset=3500).
# Fetched 100 collections on page 37 (offset=3600).
# Fetched 100 collections on page 38 (offset=3700).
# Fetched 100 collections on page 39 (offset=3800).
# Fetched 100 collections on page 40 (offset=3900).
# Fetched 100 collections on page 41 (offset=4000).
# Fetched 100 collections on page 42 (offset=4100).
# Fetched 100 collections on page 43 (offset=4200).
# Fetched 100 collections on page 44 (offset=4300).
# Fetched 100 collections on page 45 (offset=4400).
# Fetched 100 collections on page 46 (offset=4500).
# Fetched 100 collections on page 47 (offset=4600).
# Fetched 100 collections on page 48 (offset=4700).
# Fetched 100 collections on page 49 (offset=4800).
# Fetched 100 collections on page 50 (offset=4900).
# Fetched 100 collections on page 51 (offset=5000).
# Fetched 100 collections on page 52 (offset=5100).
# Fetched 100 collections on page 53 (offset=5200).
# Fetched 100 collections on page 54 (offset=5300).
# Fetched 100 collections on page 55 (offset=5400).
# Fetched 100 collections on page 56 (offset=5500).
# Fetched 100 collections on page 57 (offset=5600).
# Fetched 100 collections on page 58 (offset=5700).
# Fetched 100 collections on page 59 (offset=5800).
# Fetched 100 collections on page 60 (offset=5900).
# Fetched 100 collections on page 61 (offset=6000).
# Fetched 100 collections on page 62 (offset=6100).
# Fetched 100 collections on page 63 (offset=6200).
# Fetched 100 collections on page 64 (offset=6300).
# Fetched 100 collections on page 65 (offset=6400).
# Fetched 100 collections on page 66 (offset=6500).
# Fetched 100 collections on page 67 (offset=6600).
# Fetched 100 collections on page 68 (offset=6700).
# Fetched 100 collections on page 69 (offset=6800).
# Fetched 100 collections on page 70 (offset=6900).
# Fetched 100 collections on page 71 (offset=7000).
# Fetched 100 collections on page 72 (offset=7100).
# Fetched 100 collections on page 73 (offset=7200).
# Fetched 100 collections on page 74 (offset=7300).
# Fetched 100 collections on page 75 (offset=7400).
# Fetched 100 collections on page 76 (offset=7500).
# Fetched 100 collections on page 77 (offset=7600).
# Fetched 100 collections on page 78 (offset=7700).
# Fetched 100 collections on page 79 (offset=7800).
# Fetched 100 collections on page 80 (offset=7900).
# Fetched 100 collections on page 81 (offset=8000).
# Fetched 100 collections on page 82 (offset=8100).
# Fetched 100 collections on page 83 (offset=8200).
# Fetched 100 collections on page 84 (offset=8300).
# Fetched 100 collections on page 85 (offset=8400).
# Fetched 100 collections on page 86 (offset=8500).
# Fetched 100 collections on page 87 (offset=8600).
# Fetched 100 collections on page 88 (offset=8700).
# Fetched 100 collections on page 89 (offset=8800).
# Fetched 100 collections on page 90 (offset=8900).
# Fetched 100 collections on page 91 (offset=9000).
# Fetched 100 collections on page 92 (offset=9100).
# Fetched 100 collections on page 93 (offset=9200).
# Fetched 100 collections on page 94 (offset=9300).
# Fetched 100 collections on page 95 (offset=9400).
# Fetched 100 collections on page 96 (offset=9500).
# Fetched 100 collections on page 97 (offset=9600).
# Fetched 100 collections on page 98 (offset=9700).
# Fetched 100 collections on page 99 (offset=9800).
# Fetched 100 collections on page 100 (offset=9900).
# Fetched 100 collections on page 101 (offset=10000).
# Fetched 100 collections on page 102 (offset=10100).
# Fetched 100 collections on page 103 (offset=10200).
# Fetched 100 collections on page 104 (offset=10300).
# Fetched 100 collections on page 105 (offset=10400).
# Fetched 100 collections on page 106 (offset=10500).
# Fetched 100 collections on page 107 (offset=10600).
# Fetched 100 collections on page 108 (offset=10700).
# Fetched 100 collections on page 109 (offset=10800).
# Fetched 100 collections on page 110 (offset=10900).
# Fetched 100 collections on page 111 (offset=11000).
# Fetched 100 collections on page 112 (offset=11100).
# Fetched 100 collections on page 113 (offset=11200).
# Fetched 100 collections on page 114 (offset=11300).
# Fetched 100 collections on page 115 (offset=11400).
# Fetched 100 collections on page 116 (offset=11500).
# Fetched 100 collections on page 117 (offset=11600).
# Fetched 100 collections on page 118 (offset=11700).
# Fetched 100 collections on page 119 (offset=11800).
# Fetched 100 collections on page 120 (offset=11900).
# Fetched 100 collections on page 121 (offset=12000).
# Fetched 100 collections on page 122 (offset=12100).
# Fetched 100 collections on page 123 (offset=12200).
# Fetched 100 collections on page 124 (offset=12300).
# Fetched 100 collections on page 125 (offset=12400).
# Fetched 100 collections on page 126 (offset=12500).
# Fetched 100 collections on page 127 (offset=12600).
# Fetched 100 collections on page 128 (offset=12700).
# Fetched 100 collections on page 129 (offset=12800).
# Fetched 100 collections on page 130 (offset=12900).
# Fetched 100 collections on page 131 (offset=13000).
# Fetched 100 collections on page 132 (offset=13100).
# Fetched 100 collections on page 133 (offset=13200).
# Fetched 100 collections on page 134 (offset=13300).
# Fetched 100 collections on page 135 (offset=13400).
# Fetched 100 collections on page 136 (offset=13500).
# Fetched 100 collections on page 137 (offset=13600).
# Fetched 100 collections on page 138 (offset=13700).
# Fetched 100 collections on page 139 (offset=13800).
# Fetched 100 collections on page 140 (offset=13900).
# Fetched 100 collections on page 141 (offset=14000).
# Fetched 100 collections on page 142 (offset=14100).
# Fetched 100 collections on page 143 (offset=14200).
# Fetched 100 collections on page 144 (offset=14300).
# Fetched 100 collections on page 145 (offset=14400).
# Fetched 100 collections on page 146 (offset=14500).
# Fetched 100 collections on page 147 (offset=14600).
# Fetched 100 collections on page 148 (offset=14700).
# Fetched 100 collections on page 149 (offset=14800).
# Fetched 100 collections on page 150 (offset=14900).
# Fetched 100 collections on page 151 (offset=15000).
# Fetched 100 collections on page 152 (offset=15100).
# Fetched 100 collections on page 153 (offset=15200).
# Fetched 100 collections on page 154 (offset=15300).
# Fetched 100 collections on page 155 (offset=15400).
# Fetched 100 collections on page 156 (offset=15500).
# Fetched 100 collections on page 157 (offset=15600).
# Fetched 100 collections on page 158 (offset=15700).
# Fetched 100 collections on page 159 (offset=15800).
# Fetched 100 collections on page 160 (offset=15900).
# Fetched 100 collections on page 161 (offset=16000).
# Fetched 100 collections on page 162 (offset=16100).
# Fetched 100 collections on page 163 (offset=16200).
# Fetched 100 collections on page 164 (offset=16300).
# Fetched 100 collections on page 165 (offset=16400).
# Fetched 100 collections on page 166 (offset=16500).
# Fetched 100 collections on page 167 (offset=16600).
# Fetched 100 collections on page 168 (offset=16700).
# Fetched 100 collections on page 169 (offset=16800).
# Fetched 100 collections on page 170 (offset=16900).
# Fetched 100 collections on page 171 (offset=17000).
# Fetched 100 collections on page 172 (offset=17100).
# Fetched 100 collections on page 173 (offset=17200).
# Fetched 100 collections on page 174 (offset=17300).
# Fetched 100 collections on page 175 (offset=17400).
# Fetched 100 collections on page 176 (offset=17500).
# Fetched 100 collections on page 177 (offset=17600).
# Fetched 100 collections on page 178 (offset=17700).
# Fetched 100 collections on page 179 (offset=17800).
# Fetched 100 collections on page 180 (offset=17900).
# Fetched 100 collections on page 181 (offset=18000).
# Fetched 100 collections on page 182 (offset=18100).
# Fetched 100 collections on page 183 (offset=18200).
# Fetched 100 collections on page 184 (offset=18300).
# Fetched 100 collections on page 185 (offset=18400).
# Fetched 100 collections on page 186 (offset=18500).
# Fetched 100 collections on page 187 (offset=18600).
# Fetched 100 collections on page 188 (offset=18700).
# Fetched 100 collections on page 189 (offset=18800).
# Fetched 100 collections on page 190 (offset=18900).
# Fetched 100 collections on page 191 (offset=19000).
# Fetched 100 collections on page 192 (offset=19100).
# Fetched 100 collections on page 193 (offset=19200).
# Fetched 100 collections on page 194 (offset=19300).
# Fetched 100 collections on page 195 (offset=19400).
# Fetched 100 collections on page 196 (offset=19500).
# Fetched 100 collections on page 197 (offset=19600).
# Fetched 100 collections on page 198 (offset=19700).
# Fetched 100 collections on page 199 (offset=19800).
# Fetched 100 collections on page 200 (offset=19900).
# Fetched 100 collections on page 201 (offset=20000).
# Fetched 100 collections on page 202 (offset=20100).
# Fetched 100 collections on page 203 (offset=20200).
# Fetched 100 collections on page 204 (offset=20300).
# Fetched 100 collections on page 205 (offset=20400).
# Fetched 100 collections on page 206 (offset=20500).
# Fetched 100 collections on page 207 (offset=20600).
# Fetched 100 collections on page 208 (offset=20700).
# Fetched 100 collections on page 209 (offset=20800).
# Fetched 100 collections on page 210 (offset=20900).
# Fetched 100 collections on page 211 (offset=21000).
# Fetched 100 collections on page 212 (offset=21100).
# Fetched 100 collections on page 213 (offset=21200).
# Fetched 100 collections on page 214 (offset=21300).
# Fetched 100 collections on page 215 (offset=21400).
# Fetched 100 collections on page 216 (offset=21500).
# Fetched 100 collections on page 217 (offset=21600).
# Fetched 100 collections on page 218 (offset=21700).
# Fetched 100 collections on page 219 (offset=21800).
# Fetched 100 collections on page 220 (offset=21900).
# Fetched 100 collections on page 221 (offset=22000).
# Fetched 100 collections on page 222 (offset=22100).
# Fetched 100 collections on page 223 (offset=22200).
# Fetched 100 collections on page 224 (offset=22300).
# Fetched 100 collections on page 225 (offset=22400).
# Fetched 100 collections on page 226 (offset=22500).
# Fetched 100 collections on page 227 (offset=22600).
# Fetched 100 collections on page 228 (offset=22700).
# Fetched 100 collections on page 229 (offset=22800).
# Fetched 100 collections on page 230 (offset=22900).
# Fetched 100 collections on page 231 (offset=23000).
# Fetched 100 collections on page 232 (offset=23100).
# Fetched 100 collections on page 233 (offset=23200).
# Fetched 100 collections on page 234 (offset=23300).
# Fetched 100 collections on page 235 (offset=23400).
# Fetched 100 collections on page 236 (offset=23500).
# Fetched 100 collections on page 237 (offset=23600).
# Fetched 100 collections on page 238 (offset=23700).
# Fetched 100 collections on page 239 (offset=23800).
# Fetched 100 collections on page 240 (offset=23900).
# Fetched 100 collections on page 241 (offset=24000).
# Fetched 100 collections on page 242 (offset=24100).
# Fetched 100 collections on page 243 (offset=24200).
# Fetched 100 collections on page 244 (offset=24300).
# Fetched 100 collections on page 245 (offset=24400).
# Fetched 100 collections on page 246 (offset=24500).
# Fetched 100 collections on page 247 (offset=24600).
# Fetched 100 collections on page 248 (offset=24700).
# Fetched 100 collections on page 249 (offset=24800).
# Fetched 100 collections on page 250 (offset=24900).
# Fetched 100 collections on page 251 (offset=25000).
# Fetched 100 collections on page 252 (offset=25100).
# Fetched 100 collections on page 253 (offset=25200).
# Fetched 100 collections on page 254 (offset=25300).
# Fetched 100 collections on page 255 (offset=25400).
# Fetched 100 collections on page 256 (offset=25500).
# Fetched 100 collections on page 257 (offset=25600).
# Fetched 100 collections on page 258 (offset=25700).
# Fetched 100 collections on page 259 (offset=25800).
# Fetched 100 collections on page 260 (offset=25900).
# Fetched 100 collections on page 261 (offset=26000).
# Fetched 100 collections on page 262 (offset=26100).
# Fetched 100 collections on page 263 (offset=26200).
# Fetched 100 collections on page 264 (offset=26300).
# Fetched 100 collections on page 265 (offset=26400).
# Fetched 100 collections on page 266 (offset=26500).
# Fetched 100 collections on page 267 (offset=26600).
# Fetched 100 collections on page 268 (offset=26700).
# Fetched 100 collections on page 269 (offset=26800).
# Fetched 100 collections on page 270 (offset=26900).
# Fetched 100 collections on page 271 (offset=27000).
# Fetched 100 collections on page 272 (offset=27100).
# Fetched 100 collections on page 273 (offset=27200).
# Fetched 100 collections on page 274 (offset=27300).
# Fetched 100 collections on page 275 (offset=27400).
# Fetched 100 collections on page 276 (offset=27500).
# Fetched 100 collections on page 277 (offset=27600).
# Fetched 100 collections on page 278 (offset=27700).
# Fetched 100 collections on page 279 (offset=27800).
# Fetched 100 collections on page 280 (offset=27900).
# Fetched 100 collections on page 281 (offset=28000).
# Fetched 100 collections on page 282 (offset=28100).
# Fetched 100 collections on page 283 (offset=28200).
# Fetched 100 collections on page 284 (offset=28300).
# Fetched 100 collections on page 285 (offset=28400).
# Fetched 100 collections on page 286 (offset=28500).
# Fetched 100 collections on page 287 (offset=28600).
# Fetched 100 collections on page 288 (offset=28700).
# Fetched 100 collections on page 289 (offset=28800).
# Fetched 100 collections on page 290 (offset=28900).
# Fetched 100 collections on page 291 (offset=29000).
# Fetched 100 collections on page 292 (offset=29100).
# Fetched 100 collections on page 293 (offset=29200).
# Fetched 100 collections on page 294 (offset=29300).
# Fetched 100 collections on page 295 (offset=29400).
# Fetched 100 collections on page 296 (offset=29500).
# Fetched 100 collections on page 297 (offset=29600).
# Fetched 100 collections on page 298 (offset=29700).
# Fetched 100 collections on page 299 (offset=29800).
# Fetched 100 collections on page 300 (offset=29900).
# Fetched 100 collections on page 301 (offset=30000).
# 400 Bad Request: {"msg":"offset and limit must be a multiple of 20, offset must be a multiple of the limit"}
# Likely reached an internal offset limit or no more data is available.
# Finished scraping. Total pages: 301

# %% [markdown]
# # Atomic Market

# %%
def create_table_if_not_exists(conn):
    """
    Creates a table 'atomic_collections' if it doesn't exist already.
    We'll store the fields returned by the API for each collection.
    """
    create_sql = """
    CREATE TABLE IF NOT EXISTS atomic_collections (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        contract TEXT,
        collection_name TEXT,
        name TEXT,
        author TEXT,
        allow_notify INTEGER,
        authorized_accounts TEXT,  -- will store as JSON array
        notify_accounts TEXT,      -- also JSON
        market_fee REAL,
        data_json TEXT,            -- entire data field as JSON
        created_at_block TEXT,
        created_at_time TEXT,
        inserted_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
    """
    conn.execute(create_sql)
    conn.commit()


def insert_collections(conn, collections):
    """
    Insert a list of collections into the 'atomic_collections' table.
    Each 'collection' is a dict with fields like:
        'contract', 'collection_name', 'name', 'author', 'allow_notify', etc.
    """
    insert_sql = """
    INSERT INTO atomic_collections (
        contract,
        collection_name,
        name,
        author,
        allow_notify,
        authorized_accounts,
        notify_accounts,
        market_fee,
        data_json,
        created_at_block,
        created_at_time
    ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """

    records = []
    for coll in collections:
        contract = coll.get("contract", "")
        collection_name = coll.get("collection_name", "")
        name = coll.get("name", "")
        author = coll.get("author", "")
        
        # Booleans can be stored as 0/1 in SQLite
        allow_notify = 1 if coll.get("allow_notify", False) else 0
        
        # authorized_accounts and notify_accounts are arrays
        authorized_accounts = json.dumps(coll.get("authorized_accounts", []))
        notify_accounts = json.dumps(coll.get("notify_accounts", []))
        
        market_fee = coll.get("market_fee", 0.0)
        
        # 'data' is an object with dynamic fields. Store as JSON
        data_field = coll.get("data", {})
        data_json = json.dumps(data_field)
        
        created_at_block = coll.get("created_at_block", "")
        created_at_time = coll.get("created_at_time", "")
        
        record = (
            contract,
            collection_name,
            name,
            author,
            allow_notify,
            authorized_accounts,
            notify_accounts,
            market_fee,
            data_json,
            created_at_block,
            created_at_time
        )
        records.append(record)
    
    conn.executemany(insert_sql, records)
    conn.commit()


def fetch_atomic_collections(page=1, limit=100, order="desc", sort="created"):
    """
    Fetch collections for a given page from the AtomicAssets /v1/collections endpoint.
    Returns the parsed JSON 'data' if success, or None if an error occurs.
    
    By default:
        page=1, limit=100, order=desc, sort=created
    """
    base_url = "https://wax.api.atomicassets.io/atomicassets/v1/collections"
    params = {
        "page": page,
        "limit": limit,
        "order": order,
        "sort": sort
    }
    try:
        response = requests.get(base_url, params=params, timeout=15)
        if response.status_code != 200:
            print(f"Non-200 status: {response.status_code} => {response.text}")
            return None
        
        data = response.json()
        # data structure: { "success": true/false, "data": [...], "query_time": 0 }
        if not data.get("success", False):
            print("API returned success=false.")
            return None
        
        return data.get("data", [])
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return None


def scrape_atomic_collections(max_pages=None):
    """
    Paginated loop to fetch all possible collections (or up to max_pages if set).
    Each page has up to 100 results. We'll stop once we get an empty list or reach max_pages.
    """
    conn = sqlite3.connect("atomic_collections.db")
    create_table_if_not_exists(conn)

    page = 1
    total_fetched = 0

    while True:
        collections_data = fetch_atomic_collections(page=page, limit=100, order="desc", sort="created")
        if not collections_data:
            print(f"No more data returned or error on page {page}, stopping.")
            break
        
        # Insert into DB
        insert_collections(conn, collections_data)
        fetched_now = len(collections_data)
        total_fetched += fetched_now
        print(f"Page {page} fetched {fetched_now}, total so far: {total_fetched}")

        # If fewer than 100 returned, we might be at the end
        if fetched_now < 100:
            print("Fewer than 100 returned, presumably last page.")
            break
        
        page += 1

        # Optional: If you have a max_pages limit
        if max_pages and page > max_pages:
            print(f"Reached max_pages={max_pages}. Stopping.")
            break

        # Optional short delay to avoid rate-limiting or be kind to server
        # time.sleep(0.2)
    
    conn.close()
    print(f"Finished scraping. Total collections fetched: {total_fetched}")

# %%
if __name__ == "__main__":
    # Example: collect all pages until no more data or an error arises
    scrape_atomic_collections(max_pages=None)
# Out:
# Page 1 fetched 100, total so far: 100
# Page 2 fetched 100, total so far: 200
# Page 3 fetched 100, total so far: 300
# Page 4 fetched 100, total so far: 400
# Page 5 fetched 100, total so far: 500
# Page 6 fetched 100, total so far: 600
# Page 7 fetched 100, total so far: 700
# Page 8 fetched 100, total so far: 800
# Page 9 fetched 100, total so far: 900
# Page 10 fetched 100, total so far: 1000
# Page 11 fetched 100, total so far: 1100
# Page 12 fetched 100, total so far: 1200
# Page 13 fetched 100, total so far: 1300
# Page 14 fetched 100, total so far: 1400
# Page 15 fetched 100, total so far: 1500
# Page 16 fetched 100, total so far: 1600
# Page 17 fetched 100, total so far: 1700
# Page 18 fetched 100, total so far: 1800
# Page 19 fetched 100, total so far: 1900
# Page 20 fetched 100, total so far: 2000
# Page 21 fetched 100, total so far: 2100
# Page 22 fetched 100, total so far: 2200
# Page 23 fetched 100, total so far: 2300
# Page 24 fetched 100, total so far: 2400
# Page 25 fetched 100, total so far: 2500
# Page 26 fetched 100, total so far: 2600
# Page 27 fetched 100, total so far: 2700
# Page 28 fetched 100, total so far: 2800
# Page 29 fetched 100, total so far: 2900
# Page 30 fetched 100, total so far: 3000
# Page 31 fetched 100, total so far: 3100
# Page 32 fetched 100, total so far: 3200
# Page 33 fetched 100, total so far: 3300
# Page 34 fetched 100, total so far: 3400
# Page 35 fetched 100, total so far: 3500
# Page 36 fetched 100, total so far: 3600
